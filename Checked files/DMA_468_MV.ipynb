# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib as mpl
from datetime import datetime
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation
from sklearn.model_selection import train_test_split

from keras.callbacks import EarlyStopping
mpl.rcParams['figure.figsize'] = (20, 15)
mpl.rcParams['axes.grid'] = False
import tensorflow as tf 
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls'/content/gdrive/My Drive/Thesis'
# Out:
# dataframe_dma_flow_1D.csv     dataframe_flow_variable_1D.csv     DMA_468.csv
# dataframe_dma_flow_60min.csv  dataframe_flow_variable_60min.csv
# dataframe_flow_1D.csv         DMA_225.csv

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/dataframe_flow_variable_60min.csv")
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'])
data.rename( columns={'Unnamed: 0':'Date_time','468':'DMA_468'}, inplace=True )

# %%
data_DMA468 = data[['Date_time','DMA_468','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']]
data_DMA468.shape
# Out:
# (2208, 10)

# %%
data_DMA468_indexed = data_DMA468.set_index('Date_time')
data_DMA468_indexed[['DMA_468','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']].plot(subplots=True)
plt.figure(figsize=(20, 20))

# %%
data_DMA468_indexed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2208 entries, 2016-04-22 00:00:00 to 2016-07-22 23:00:00
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DMA_468        2208 non-null   float64
#  1   tempC          2208 non-null   int64
#  2   HeatIndexC     2208 non-null   int64
#  3   FeelsLikeC     2208 non-null   int64
#  4   WindChillC     2208 non-null   int64
#  5   windspeedKmph  2208 non-null   int64
#  6   sunHour        2208 non-null   float64
#  7   precipMM       2208 non-null   float64
#  8   humidity       2208 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 172.5 KB

# %%
# Making hourly data 
hourly_data = data_DMA468_indexed.resample('h').sum()

hourly_data.isnull().sum().sum()
hourly_data.isna().sum().sum()
data_hourly = hourly_data.values
#Scaling the data 
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_hourly)
scaled_hourlydata = pd.DataFrame(scaled_data)

# Restructuring the data
def reshaped_hourlydata(data,step_input,step_output):
  final_data =  np.array([data[i:i + (step_input+step_output)].copy() for i in range(len(data) - (step_input+step_output))])
  return final_data

final_hourlydata = reshaped_hourlydata(scaled_hourlydata,12,24)
final_hourlydata.shape
# Out:
# (2172, 36, 9)

# %%
train_size = int(len(final_hourlydata)*0.6)
remaining_data = len(final_hourlydata) - train_size
# With the remaining data 70% is considered for validation set and 30% for test set.
validation_data = int((remaining_data)*0.7)
testing_data = remaining_data-validation_data
valid_size = (train_size)+(validation_data)
# Restructing the dataset:
step_input = 12
step_output = 24

train_X = final_hourlydata[:train_size, :step_input]
valid_X = final_hourlydata[train_size:valid_size, :step_input]
test_X = final_hourlydata[valid_size:, :step_input]
y = np.empty((len(final_hourlydata), step_input, step_output))
for future_value in range(1, step_output + 1):
    y[..., future_value - 1] = final_hourlydata[..., future_value:future_value + step_input, 0]
train_y = y[:train_size]
valid_y = y[train_size:valid_size]
test_y = y[valid_size:]

print("The shape of train_X is:",train_X.shape)
print("The shape of valid_X is:",valid_X.shape)
print("The shape of test_X is:",test_X.shape)

print("The shape of train_y is:",train_y.shape)
print("The shape of valid_y is:",valid_y.shape)
print("The shape of test_y is:",test_y.shape)
# Out:
# The shape of train_X is: (1303, 12, 9)
# The shape of valid_X is: (608, 12, 9)
# The shape of test_X is: (261, 12, 9)
# The shape of train_y is: (1303, 12, 24)
# The shape of valid_y is: (608, 12, 24)
# The shape of test_y is: (261, 12, 24)

# %%
model1 = keras.models.Sequential([
keras.layers.LSTM(100,return_sequences=True, input_shape=(12,9)),
keras.layers.Dropout(0.1),
keras.layers.Dense(100,kernel_initializer='normal'),
keras.layers.Dense(70,kernel_initializer='normal'),
keras.layers.Dropout(0.37),
keras.layers.Dense(24)
])

model1.compile(loss='mae', optimizer='adam'),
history1= model1.fit(train_X,train_y, batch_size = 50,epochs = 250,validation_data=(valid_X, valid_y))
# Out:
# Epoch 1/250
# 27/27 [==============================] - 3s 39ms/step - loss: 0.2161 - val_loss: 0.1512
# Epoch 2/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1685 - val_loss: 0.1355
# Epoch 3/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1521 - val_loss: 0.1223
# Epoch 4/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1412 - val_loss: 0.1181
# Epoch 5/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1360 - val_loss: 0.1130
# Epoch 6/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1313 - val_loss: 0.1095
# Epoch 7/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.1267 - val_loss: 0.1029
# Epoch 8/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1224 - val_loss: 0.0983
# Epoch 9/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1183 - val_loss: 0.0939
# Epoch 10/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1149 - val_loss: 0.0974
# Epoch 11/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1129 - val_loss: 0.0940
# Epoch 12/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1106 - val_loss: 0.0912
# Epoch 13/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1097 - val_loss: 0.0910
# Epoch 14/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1082 - val_loss: 0.0889
# Epoch 15/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1074 - val_loss: 0.0930
# Epoch 16/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1068 - val_loss: 0.0902
# Epoch 17/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1057 - val_loss: 0.0886
# Epoch 18/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1050 - val_loss: 0.0924
# Epoch 19/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1039 - val_loss: 0.0939
# Epoch 20/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1043 - val_loss: 0.0901
# Epoch 21/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1031 - val_loss: 0.0873
# Epoch 22/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1024 - val_loss: 0.0880
# Epoch 23/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1016 - val_loss: 0.0868
# Epoch 24/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1002 - val_loss: 0.0869
# Epoch 25/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1002 - val_loss: 0.0861
# Epoch 26/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0998 - val_loss: 0.0853
# Epoch 27/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0991 - val_loss: 0.0851
# Epoch 28/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0983 - val_loss: 0.0854
# Epoch 29/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0986 - val_loss: 0.0848
# Epoch 30/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0972 - val_loss: 0.0872
# Epoch 31/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0972 - val_loss: 0.0834
# Epoch 32/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0965 - val_loss: 0.0833
# Epoch 33/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0957 - val_loss: 0.0834
# Epoch 34/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0959 - val_loss: 0.0837
# Epoch 35/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0954 - val_loss: 0.0831
# Epoch 36/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0957 - val_loss: 0.0846
# Epoch 37/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0942 - val_loss: 0.0812
# Epoch 38/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0937 - val_loss: 0.0844
# Epoch 39/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0937 - val_loss: 0.0816
# Epoch 40/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0933 - val_loss: 0.0811
# Epoch 41/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0926 - val_loss: 0.0796
# Epoch 42/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0921 - val_loss: 0.0809
# Epoch 43/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0918 - val_loss: 0.0797
# Epoch 44/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0911 - val_loss: 0.0804
# Epoch 45/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0914 - val_loss: 0.0811
# Epoch 46/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0903 - val_loss: 0.0805
# Epoch 47/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0909 - val_loss: 0.0814
# Epoch 48/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0906 - val_loss: 0.0789
# Epoch 49/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0897 - val_loss: 0.0791
# Epoch 50/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0889 - val_loss: 0.0811
# Epoch 51/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0891 - val_loss: 0.0776
# Epoch 52/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0883 - val_loss: 0.0793
# Epoch 53/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0882 - val_loss: 0.0773
# Epoch 54/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0881 - val_loss: 0.0765
# Epoch 55/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0878 - val_loss: 0.0767
# Epoch 56/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0876 - val_loss: 0.0773
# Epoch 57/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0868 - val_loss: 0.0783
# Epoch 58/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0866 - val_loss: 0.0775
# Epoch 59/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0869 - val_loss: 0.0787
# Epoch 60/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0871 - val_loss: 0.0779
# Epoch 61/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0861 - val_loss: 0.0761
# Epoch 62/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0866 - val_loss: 0.0782
# Epoch 63/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0855 - val_loss: 0.0759
# Epoch 64/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0856 - val_loss: 0.0783
# Epoch 65/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0857 - val_loss: 0.0799
# Epoch 66/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0851 - val_loss: 0.0761
# Epoch 67/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0847 - val_loss: 0.0779
# Epoch 68/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0853 - val_loss: 0.0769
# Epoch 69/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0848 - val_loss: 0.0772
# Epoch 70/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0839 - val_loss: 0.0781
# Epoch 71/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0839 - val_loss: 0.0792
# Epoch 72/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0846 - val_loss: 0.0748
# Epoch 73/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0838 - val_loss: 0.0770
# Epoch 74/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0839 - val_loss: 0.0742
# Epoch 75/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0837 - val_loss: 0.0771
# Epoch 76/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0838 - val_loss: 0.0744
# Epoch 77/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0832 - val_loss: 0.0767
# Epoch 78/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0832 - val_loss: 0.0771
# Epoch 79/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0830 - val_loss: 0.0764
# Epoch 80/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0823 - val_loss: 0.0763
# Epoch 81/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0830 - val_loss: 0.0763
# Epoch 82/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0825 - val_loss: 0.0766
# Epoch 83/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0822 - val_loss: 0.0753
# Epoch 84/250
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0815 - val_loss: 0.0756
# Epoch 85/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0815 - val_loss: 0.0744
# Epoch 86/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0821 - val_loss: 0.0764
# Epoch 87/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0819 - val_loss: 0.0757
# Epoch 88/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0818 - val_loss: 0.0760
# Epoch 89/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0811 - val_loss: 0.0759
# Epoch 90/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0814 - val_loss: 0.0729
# Epoch 91/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0814 - val_loss: 0.0742
# Epoch 92/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0814 - val_loss: 0.0751
# Epoch 93/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0812 - val_loss: 0.0759
# Epoch 94/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0806 - val_loss: 0.0738
# Epoch 95/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0804 - val_loss: 0.0746
# Epoch 96/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0802 - val_loss: 0.0737
# Epoch 97/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0801 - val_loss: 0.0739
# Epoch 98/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0800 - val_loss: 0.0745
# Epoch 99/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0798 - val_loss: 0.0734
# Epoch 100/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0798 - val_loss: 0.0723
# Epoch 101/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0802 - val_loss: 0.0735
# Epoch 102/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0796 - val_loss: 0.0732
# Epoch 103/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0798 - val_loss: 0.0732
# Epoch 104/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0791 - val_loss: 0.0746
# Epoch 105/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0794 - val_loss: 0.0740
# Epoch 106/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0802 - val_loss: 0.0751
# Epoch 107/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0801 - val_loss: 0.0738
# Epoch 108/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0792 - val_loss: 0.0728
# Epoch 109/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0789 - val_loss: 0.0745
# Epoch 110/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0791 - val_loss: 0.0743
# Epoch 111/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0787 - val_loss: 0.0723
# Epoch 112/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0790 - val_loss: 0.0742
# Epoch 113/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0795 - val_loss: 0.0735
# Epoch 114/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0782 - val_loss: 0.0754
# Epoch 115/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0786 - val_loss: 0.0718
# Epoch 116/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0789 - val_loss: 0.0735
# Epoch 117/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0787 - val_loss: 0.0728
# Epoch 118/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0787 - val_loss: 0.0716
# Epoch 119/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0786 - val_loss: 0.0736
# Epoch 120/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0784 - val_loss: 0.0720
# Epoch 121/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0782 - val_loss: 0.0723
# Epoch 122/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0783 - val_loss: 0.0722
# Epoch 123/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0780 - val_loss: 0.0734
# Epoch 124/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0781 - val_loss: 0.0756
# Epoch 125/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0784 - val_loss: 0.0711
# Epoch 126/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0778 - val_loss: 0.0726
# Epoch 127/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0774 - val_loss: 0.0710
# Epoch 128/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0778 - val_loss: 0.0720
# Epoch 129/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0779 - val_loss: 0.0710
# Epoch 130/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0769 - val_loss: 0.0719
# Epoch 131/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0770 - val_loss: 0.0720
# Epoch 132/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0768 - val_loss: 0.0737
# Epoch 133/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0769 - val_loss: 0.0725
# Epoch 134/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0770 - val_loss: 0.0743
# Epoch 135/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0771 - val_loss: 0.0734
# Epoch 136/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0771 - val_loss: 0.0732
# Epoch 137/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0764 - val_loss: 0.0712
# Epoch 138/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0773 - val_loss: 0.0715
# Epoch 139/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0769 - val_loss: 0.0723
# Epoch 140/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0767 - val_loss: 0.0712
# Epoch 141/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0765 - val_loss: 0.0713
# Epoch 142/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0763 - val_loss: 0.0701
# Epoch 143/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0767 - val_loss: 0.0735
# Epoch 144/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0768 - val_loss: 0.0733
# Epoch 145/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0772 - val_loss: 0.0727
# Epoch 146/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0767 - val_loss: 0.0731
# Epoch 147/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0764 - val_loss: 0.0713
# Epoch 148/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0764 - val_loss: 0.0713
# Epoch 149/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0761 - val_loss: 0.0726
# Epoch 150/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0762 - val_loss: 0.0726
# Epoch 151/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0761 - val_loss: 0.0735
# Epoch 152/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0762 - val_loss: 0.0722
# Epoch 153/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0759 - val_loss: 0.0721
# Epoch 154/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0757 - val_loss: 0.0708
# Epoch 155/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0758 - val_loss: 0.0718
# Epoch 156/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0760 - val_loss: 0.0715
# Epoch 157/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0758 - val_loss: 0.0738
# Epoch 158/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0757 - val_loss: 0.0731
# Epoch 159/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0755 - val_loss: 0.0718
# Epoch 160/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0753 - val_loss: 0.0718
# Epoch 161/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0751 - val_loss: 0.0722
# Epoch 162/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0754 - val_loss: 0.0713
# Epoch 163/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0754 - val_loss: 0.0743
# Epoch 164/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0753 - val_loss: 0.0719
# Epoch 165/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0751 - val_loss: 0.0720
# Epoch 166/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0753 - val_loss: 0.0719
# Epoch 167/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0752 - val_loss: 0.0733
# Epoch 168/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0752 - val_loss: 0.0736
# Epoch 169/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0753 - val_loss: 0.0720
# Epoch 170/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0752 - val_loss: 0.0714
# Epoch 171/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0748 - val_loss: 0.0716
# Epoch 172/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0751 - val_loss: 0.0713
# Epoch 173/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0748 - val_loss: 0.0718
# Epoch 174/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0744 - val_loss: 0.0706
# Epoch 175/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0747 - val_loss: 0.0726
# Epoch 176/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0747 - val_loss: 0.0737
# Epoch 177/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0747 - val_loss: 0.0704
# Epoch 178/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0741 - val_loss: 0.0713
# Epoch 179/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0745 - val_loss: 0.0712
# Epoch 180/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0745 - val_loss: 0.0730
# Epoch 181/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0743 - val_loss: 0.0710
# Epoch 182/250
# 27/27 [==============================] - 1s 24ms/step - loss: 0.0744 - val_loss: 0.0715
# Epoch 183/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0741 - val_loss: 0.0724
# Epoch 184/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0741 - val_loss: 0.0697
# Epoch 185/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0741 - val_loss: 0.0705
# Epoch 186/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0741 - val_loss: 0.0707
# Epoch 187/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0737 - val_loss: 0.0720
# Epoch 188/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0739 - val_loss: 0.0733
# Epoch 189/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0741 - val_loss: 0.0722
# Epoch 190/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0739 - val_loss: 0.0725
# Epoch 191/250
# 27/27 [==============================] - 1s 22ms/step - loss: 0.0740 - val_loss: 0.0723
# Epoch 192/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0738 - val_loss: 0.0713
# Epoch 193/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0740 - val_loss: 0.0731
# Epoch 194/250
# 27/27 [==============================] - 1s 19ms/step - loss: 0.0738 - val_loss: 0.0726
# Epoch 195/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0739 - val_loss: 0.0720
# Epoch 196/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0735 - val_loss: 0.0710
# Epoch 197/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0732 - val_loss: 0.0722
# Epoch 198/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0734 - val_loss: 0.0734
# Epoch 199/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0734 - val_loss: 0.0714
# Epoch 200/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0734 - val_loss: 0.0714
# Epoch 201/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0738 - val_loss: 0.0731
# Epoch 202/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0733 - val_loss: 0.0719
# Epoch 203/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0733 - val_loss: 0.0695
# Epoch 204/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0733 - val_loss: 0.0712
# Epoch 205/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0731 - val_loss: 0.0713
# Epoch 206/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0729 - val_loss: 0.0724
# Epoch 207/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0731 - val_loss: 0.0713
# Epoch 208/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0728 - val_loss: 0.0694
# Epoch 209/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0731 - val_loss: 0.0719
# Epoch 210/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0728 - val_loss: 0.0722
# Epoch 211/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0731 - val_loss: 0.0733
# Epoch 212/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0735 - val_loss: 0.0722
# Epoch 213/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0726 - val_loss: 0.0717
# Epoch 214/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0728 - val_loss: 0.0715
# Epoch 215/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0728 - val_loss: 0.0726
# Epoch 216/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0727 - val_loss: 0.0729
# Epoch 217/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0731 - val_loss: 0.0715
# Epoch 218/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0728 - val_loss: 0.0715
# Epoch 219/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0726 - val_loss: 0.0728
# Epoch 220/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 221/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0729 - val_loss: 0.0740
# Epoch 222/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0725 - val_loss: 0.0729
# Epoch 223/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0729 - val_loss: 0.0735
# Epoch 224/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0723 - val_loss: 0.0721
# Epoch 225/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0722 - val_loss: 0.0729
# Epoch 226/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0722 - val_loss: 0.0714
# Epoch 227/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0724 - val_loss: 0.0706
# Epoch 228/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0723 - val_loss: 0.0713
# Epoch 229/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0721 - val_loss: 0.0733
# Epoch 230/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0725 - val_loss: 0.0731
# Epoch 231/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0720 - val_loss: 0.0753
# Epoch 232/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0729 - val_loss: 0.0748
# Epoch 233/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0724 - val_loss: 0.0736
# Epoch 234/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0719 - val_loss: 0.0739
# Epoch 235/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0720 - val_loss: 0.0740
# Epoch 236/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0722 - val_loss: 0.0714
# Epoch 237/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0717 - val_loss: 0.0717
# Epoch 238/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0714 - val_loss: 0.0723
# Epoch 239/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0717 - val_loss: 0.0727
# Epoch 240/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0719 - val_loss: 0.0731
# Epoch 241/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0719 - val_loss: 0.0732
# Epoch 242/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0715 - val_loss: 0.0726
# Epoch 243/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0714 - val_loss: 0.0723
# Epoch 244/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0716 - val_loss: 0.0725
# Epoch 245/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0714 - val_loss: 0.0712
# Epoch 246/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0718 - val_loss: 0.0726
# Epoch 247/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0712 - val_loss: 0.0724
# Epoch 248/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0712 - val_loss: 0.0722
# Epoch 249/250
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0717 - val_loss: 0.0731
# Epoch 250/250
# 27/27 [==============================] - 1s 20ms/step - loss: 0.0711 - val_loss: 0.0720

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(history1,'LSTM')

# %%
#Generate predictions
train_pred = model1.predict(train_X)
#evaluation = model.evaluate(x=X_test, y=y_test, verbose=1)
test_pred = model1.predict(test_X)
predictions = test_pred

# %%
# To make a dataframe of original and predicted value:
lstm_df=[]
for i in range (0, len(predictions)):
  lstm_df.append((predictions[i][0][step_output-1]))
final_df = pd.DataFrame((test_X[:,0]))
final_df.rename(columns = {0:'original_value'}, inplace = True)
final_df['predicted_value'] = lstm_df

# %%
# To calculate the percentage difference between actual and predicted value:
final_df['total_difference'] = (final_df['predicted_value'] - final_df['original_value']).abs()
final_df['percentage_difference'] = ((final_df['total_difference'])/(final_df['original_value']))*100

# %%
import math
from sklearn.metrics import mean_squared_error
#testset = math.sqrt(mean_squared_error(final_df['original_value'], final_df['predicted_value']))
testset = math.sqrt(mean_squared_error(final_df['original_value'], final_df['predicted_value']))
print("The RMSE prediction value on testset: ",testset)
# Out:
# The RMSE prediction value on testset:  0.037053395172674364

# %%
# To make complete df:
y = [y[0] for y in test_y]
df_r = hourly_data.reset_index()
days = df_r['Date_time'].values[-len(y):]
df = pd.DataFrame(days,columns = ['Date_time'])
result = pd.concat([df, final_df], axis=1, join='inner')
result.shape
# Out:
# (261, 13)

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(result.Date_time, result.original_value, color='red', label='original')
plt.plot(result.Date_time, result.predicted_value, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()

# %%
from google.colab import files

# e.g. save pandas output as csv
result.to_csv('DMA_468_MLSTM.csv')

# or any other file as usual
# with open('example.csv', 'w') as f:
#   f.write('your strings here')

files.download('DMA_468_MLSTM.csv')
