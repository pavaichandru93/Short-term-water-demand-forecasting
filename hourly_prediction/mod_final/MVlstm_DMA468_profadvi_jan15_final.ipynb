# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib as mpl
from datetime import datetime
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM,LeakyReLU,ReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation


from keras.callbacks import EarlyStopping
mpl.rcParams['figure.figsize'] = (20, 15)
mpl.rcParams['axes.grid'] = False
import tensorflow as tf 
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls'/content/gdrive/My Drive/Thesis'
# Out:
# dataframe_dma_flow_1D.csv       dataframe_flow_variable_60min.csv
# dataframe_dma_flow_60min.csv    DMA_225.csv
# dataframe_flow_1D.csv           DMA_468.csv
# dataframe_flow_variable_1D.csv  persistence_results.pkl

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/dataframe_flow_variable_60min.csv")
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'])
data.rename( columns={'Unnamed: 0':'Date_time','468':'DMA_468'}, inplace=True )

# %%
data_DMA468 = data[['Date_time','DMA_468','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']]
data_DMA468.shape
# Out:
# (2208, 10)

# %%
data_DMA468_indexed = data_DMA468.set_index('Date_time')
data_DMA468_indexed[['DMA_468','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']].plot(subplots=True)
plt.figure(figsize=(20, 20))

# %%
# Making hourly data 
hourly_data = data_DMA468_indexed.resample('h').sum()

#Train and test split
#split = 442
train = hourly_data[:-442]
test = hourly_data[-442:]

# %%
#Separate dates for future plotting
trainset = train.reset_index()
train_dates = pd.to_datetime(trainset['Date_time'])
len(train_dates)
# Out:
# 1766

# %%
#Variables for training
cols = list(train)[:10]
df_for_training = train[cols]

#LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
# normalize the dataset
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
df_for_training_scaled.shape
# Out:
# (1766, 9)

# %%
#Empty lists to be populated using formatted training data
trainX = []
trainY = []

n_future = 1   # Number of days we want to look into the future based on the past days.
n_past = 24  # Number of past days we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)
#In my example, my df_for_training_scaled has a shape (12823, 5)
#12823 refers to the number of data points and 5 refers to the columns (multi-variables).
for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))

trainX, trainY = np.array(trainX), np.array(trainY)
# Out:
# trainX shape == (1742, 24, 9).
# trainY shape == (1742, 1).

# %%
model = Sequential()
model.add(LSTM(60, activation='relu',input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LeakyReLU(alpha=0.9)) 
model.add(Dropout(0.17))
model.add(LSTM(15,return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))

model.compile(optimizer='adam', loss='mae')
model.summary()


# fit the model
history = model.fit(trainX, trainY, epochs=100, batch_size=10000, validation_split=0.2, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 60)            16800
#
#  leaky_re_lu (LeakyReLU)     (None, 24, 60)            0
#
#  dropout (Dropout)           (None, 24, 60)            0
#
#  lstm_1 (LSTM)               (None, 15)                4560
#
#  dropout_1 (Dropout)         (None, 15)                0
#
#  dense (Dense)               (None, 1)                 16
#
# =================================================================
# Total params: 21,376
# Trainable params: 21,376
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.8710 - val_loss: 0.8012
# Epoch 2/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.8550 - val_loss: 0.7926
# Epoch 3/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.8472 - val_loss: 0.7847
# Epoch 4/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.8397 - val_loss: 0.7767
# Epoch 5/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.8306 - val_loss: 0.7682
# Epoch 6/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.8200 - val_loss: 0.7596
# Epoch 7/100
# 1/1 [==============================] - 0s 350ms/step - loss: 0.8150 - val_loss: 0.7503
# Epoch 8/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.8092 - val_loss: 0.7405
# Epoch 9/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.7943 - val_loss: 0.7305
# Epoch 10/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.7904 - val_loss: 0.7205
# Epoch 11/100
# 1/1 [==============================] - 0s 347ms/step - loss: 0.7857 - val_loss: 0.7102
# Epoch 12/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.7742 - val_loss: 0.6993
# Epoch 13/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.7617 - val_loss: 0.6879
# Epoch 14/100
# 1/1 [==============================] - 0s 354ms/step - loss: 0.7501 - val_loss: 0.6764
# Epoch 15/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.7425 - val_loss: 0.6643
# Epoch 16/100
# 1/1 [==============================] - 0s 340ms/step - loss: 0.7362 - val_loss: 0.6518
# Epoch 17/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.7158 - val_loss: 0.6393
# Epoch 18/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.7176 - val_loss: 0.6267
# Epoch 19/100
# 1/1 [==============================] - 0s 339ms/step - loss: 0.6975 - val_loss: 0.6146
# Epoch 20/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.6992 - val_loss: 0.6021
# Epoch 21/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.6739 - val_loss: 0.5896
# Epoch 22/100
# 1/1 [==============================] - 0s 343ms/step - loss: 0.6598 - val_loss: 0.5770
# Epoch 23/100
# 1/1 [==============================] - 0s 351ms/step - loss: 0.6441 - val_loss: 0.5647
# Epoch 24/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.6298 - val_loss: 0.5511
# Epoch 25/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.6197 - val_loss: 0.5277
# Epoch 26/100
# 1/1 [==============================] - 0s 337ms/step - loss: 0.6045 - val_loss: 0.5221
# Epoch 27/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.5788 - val_loss: 0.5269
# Epoch 28/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.5636 - val_loss: 0.5226
# Epoch 29/100
# 1/1 [==============================] - 0s 365ms/step - loss: 0.5464 - val_loss: 0.5048
# Epoch 30/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.5424 - val_loss: 0.4772
# Epoch 31/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.5230 - val_loss: 0.4339
# Epoch 32/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.5091 - val_loss: 0.4264
# Epoch 33/100
# 1/1 [==============================] - 0s 332ms/step - loss: 0.5094 - val_loss: 0.4184
# Epoch 34/100
# 1/1 [==============================] - 0s 350ms/step - loss: 0.5012 - val_loss: 0.4128
# Epoch 35/100
# 1/1 [==============================] - 0s 342ms/step - loss: 0.4980 - val_loss: 0.4097
# Epoch 36/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.4918 - val_loss: 0.4049
# Epoch 37/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.4875 - val_loss: 0.3964
# Epoch 38/100
# 1/1 [==============================] - 0s 360ms/step - loss: 0.4711 - val_loss: 0.3836
# Epoch 39/100
# 1/1 [==============================] - 0s 347ms/step - loss: 0.4651 - val_loss: 0.3689
# Epoch 40/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.4731 - val_loss: 0.3554
# Epoch 41/100
# 1/1 [==============================] - 0s 344ms/step - loss: 0.4611 - val_loss: 0.3461
# Epoch 42/100
# 1/1 [==============================] - 0s 344ms/step - loss: 0.4592 - val_loss: 0.3401
# Epoch 43/100
# 1/1 [==============================] - 0s 337ms/step - loss: 0.4571 - val_loss: 0.3386
# Epoch 44/100
# 1/1 [==============================] - 0s 348ms/step - loss: 0.4505 - val_loss: 0.3344
# Epoch 45/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.4354 - val_loss: 0.3302
# Epoch 46/100
# 1/1 [==============================] - 0s 344ms/step - loss: 0.4390 - val_loss: 0.3291
# Epoch 47/100
# 1/1 [==============================] - 0s 342ms/step - loss: 0.4303 - val_loss: 0.3293
# Epoch 48/100
# 1/1 [==============================] - 0s 331ms/step - loss: 0.4280 - val_loss: 0.3284
# Epoch 49/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.4082 - val_loss: 0.3287
# Epoch 50/100
# 1/1 [==============================] - 0s 338ms/step - loss: 0.4123 - val_loss: 0.3263
# Epoch 51/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.4191 - val_loss: 0.3238
# Epoch 52/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.4090 - val_loss: 0.3191
# Epoch 53/100
# 1/1 [==============================] - 0s 339ms/step - loss: 0.4134 - val_loss: 0.3159
# Epoch 54/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.4064 - val_loss: 0.3168
# Epoch 55/100
# 1/1 [==============================] - 0s 339ms/step - loss: 0.3937 - val_loss: 0.3181
# Epoch 56/100
# 1/1 [==============================] - 0s 345ms/step - loss: 0.3993 - val_loss: 0.3228
# Epoch 57/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.3920 - val_loss: 0.3238
# Epoch 58/100
# 1/1 [==============================] - 0s 340ms/step - loss: 0.3995 - val_loss: 0.3165
# Epoch 59/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.3877 - val_loss: 0.3089
# Epoch 60/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.3816 - val_loss: 0.3077
# Epoch 61/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.3856 - val_loss: 0.3121
# Epoch 62/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.3760 - val_loss: 0.3204
# Epoch 63/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.3738 - val_loss: 0.3179
# Epoch 64/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.3646 - val_loss: 0.3115
# Epoch 65/100
# 1/1 [==============================] - 0s 352ms/step - loss: 0.3652 - val_loss: 0.3084
# Epoch 66/100
# 1/1 [==============================] - 0s 344ms/step - loss: 0.3614 - val_loss: 0.3098
# Epoch 67/100
# 1/1 [==============================] - 0s 353ms/step - loss: 0.3651 - val_loss: 0.3149
# Epoch 68/100
# 1/1 [==============================] - 0s 368ms/step - loss: 0.3616 - val_loss: 0.3144
# Epoch 69/100
# 1/1 [==============================] - 0s 346ms/step - loss: 0.3523 - val_loss: 0.3185
# Epoch 70/100
# 1/1 [==============================] - 0s 348ms/step - loss: 0.3521 - val_loss: 0.3311
# Epoch 71/100
# 1/1 [==============================] - 0s 353ms/step - loss: 0.3686 - val_loss: 0.3275
# Epoch 72/100
# 1/1 [==============================] - 0s 359ms/step - loss: 0.3580 - val_loss: 0.3188
# Epoch 73/100
# 1/1 [==============================] - 0s 350ms/step - loss: 0.3488 - val_loss: 0.3189
# Epoch 74/100
# 1/1 [==============================] - 0s 360ms/step - loss: 0.3425 - val_loss: 0.3201
# Epoch 75/100
# 1/1 [==============================] - 0s 340ms/step - loss: 0.3495 - val_loss: 0.3107
# Epoch 76/100
# 1/1 [==============================] - 0s 341ms/step - loss: 0.3507 - val_loss: 0.3165
# Epoch 77/100
# 1/1 [==============================] - 0s 350ms/step - loss: 0.3464 - val_loss: 0.3183
# Epoch 78/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.3397 - val_loss: 0.3161
# Epoch 79/100
# 1/1 [==============================] - 0s 346ms/step - loss: 0.3344 - val_loss: 0.3089
# Epoch 80/100
# 1/1 [==============================] - 0s 342ms/step - loss: 0.3388 - val_loss: 0.3056
# Epoch 81/100
# 1/1 [==============================] - 0s 328ms/step - loss: 0.3334 - val_loss: 0.3086
# Epoch 82/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.3375 - val_loss: 0.3146
# Epoch 83/100
# 1/1 [==============================] - 0s 339ms/step - loss: 0.3272 - val_loss: 0.3225
# Epoch 84/100
# 1/1 [==============================] - 0s 332ms/step - loss: 0.3346 - val_loss: 0.3279
# Epoch 85/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.3225 - val_loss: 0.3282
# Epoch 86/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.3278 - val_loss: 0.3243
# Epoch 87/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.3294 - val_loss: 0.3218
# Epoch 88/100
# 1/1 [==============================] - 0s 315ms/step - loss: 0.3372 - val_loss: 0.3218
# Epoch 89/100
# 1/1 [==============================] - 0s 342ms/step - loss: 0.3279 - val_loss: 0.3242
# Epoch 90/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.3299 - val_loss: 0.3283
# Epoch 91/100
# 1/1 [==============================] - 0s 327ms/step - loss: 0.3208 - val_loss: 0.3286
# Epoch 92/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.3192 - val_loss: 0.3241
# Epoch 93/100
# 1/1 [==============================] - 0s 323ms/step - loss: 0.3238 - val_loss: 0.3098
# Epoch 94/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.3196 - val_loss: 0.3069
# Epoch 95/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.3176 - val_loss: 0.3119
# Epoch 96/100
# 1/1 [==============================] - 0s 334ms/step - loss: 0.3149 - val_loss: 0.3210
# Epoch 97/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.3176 - val_loss: 0.3253
# Epoch 98/100
# 1/1 [==============================] - 0s 345ms/step - loss: 0.3122 - val_loss: 0.3169
# Epoch 99/100
# 1/1 [==============================] - 0s 320ms/step - loss: 0.3078 - val_loss: 0.3066
# Epoch 100/100
# 1/1 [==============================] - 0s 340ms/step - loss: 0.3079 - val_loss: 0.3041

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(history,'LSTM')

# %%
n_past = 24
n_days_for_prediction=264  #let us predict past 15 days

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq='1H').tolist()

#Make prediction
prediction = model.predict(trainX[-n_days_for_prediction:])
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
# Convert timestamp to date
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i)
    
df_forecast = pd.DataFrame({'Date_time':np.array(forecast_dates), 'DMA_468_pred':y_pred_future})
df_forecast['Date_time']=pd.to_datetime(df_forecast['Date_time'])

# making predicted df

df1=df_forecast[24:]
df1= df1.reset_index()
df1= df1.drop(['index'], axis=1)

# test dataset

t1 = test.reset_index()
t1 = t1[['Date_time','DMA_468']]

# %%
t1
# Out:
#               Date_time  DMA_468
# 0   2016-07-04 14:00:00  0.94150
# 1   2016-07-04 15:00:00  1.00850
# 2   2016-07-04 16:00:00  1.28350
# 3   2016-07-04 17:00:00  1.25825
# 4   2016-07-04 18:00:00  1.08900
# ..                  ...      ...
# 437 2016-07-22 19:00:00  1.26675
# 438 2016-07-22 20:00:00  1.07250
# 439 2016-07-22 21:00:00  0.98050
# 440 2016-07-22 22:00:00  0.91125
# 441 2016-07-22 23:00:00  0.45300
#
# [442 rows x 2 columns]

# %%
df1
# Out:
#               Date_time  DMA_468_pred
# 0   2016-07-04 14:00:00      1.009018
# 1   2016-07-04 15:00:00      1.086621
# 2   2016-07-04 16:00:00      1.184847
# 3   2016-07-04 17:00:00      1.263882
# 4   2016-07-04 18:00:00      1.282499
# ..                  ...           ...
# 235 2016-07-14 09:00:00      1.055390
# 236 2016-07-14 10:00:00      0.958914
# 237 2016-07-14 11:00:00      0.914933
# 238 2016-07-14 12:00:00      0.881265
# 239 2016-07-14 13:00:00      0.837712
#
# [240 rows x 2 columns]

# %%
Original = hourly_data["DMA_468"].to_frame().rename(columns = {"DMA_468": "Original" })
Forecast  = hourly_data["DMA_468"].to_frame().shift(1).rename(columns = {"DMA_468": "Forecast" })
baseline = pd.concat([Original,Forecast],axis=1)
final = baseline[1:]
baseline_graph = final[-202:]
baseline_graph = baseline_graph.reset_index()
bg = baseline_graph[['Date_time', 'Forecast']]
bg.rename( columns={'Forecast':'DMA_468_pred'}, inplace=True )
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
v = t1.iloc[-202:]
v.rename( columns={'DMA_468':'DMA_468_pred'}, inplace=True )
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
frames = [df1, bg]
  
result = pd.concat(frames)
display(result)
# Out:
#               Date_time  DMA_468_pred
# 0   2016-07-04 14:00:00      1.009018
# 1   2016-07-04 15:00:00      1.086621
# 2   2016-07-04 16:00:00      1.184847
# 3   2016-07-04 17:00:00      1.263882
# 4   2016-07-04 18:00:00      1.282499
# ..                  ...           ...
# 197 2016-07-22 19:00:00      1.366500
# 198 2016-07-22 20:00:00      1.266750
# 199 2016-07-22 21:00:00      1.072500
# 200 2016-07-22 22:00:00      0.980500
# 201 2016-07-22 23:00:00      0.911250
#
# [442 rows x 2 columns]

# %%
# final df
fd=pd.merge(t1, result, on="Date_time")

# %%
fd
# Out:
#               Date_time  DMA_468  DMA_468_pred
# 0   2016-07-04 14:00:00  0.94150      1.009018
# 1   2016-07-04 15:00:00  1.00850      1.086621
# 2   2016-07-04 16:00:00  1.28350      1.184847
# 3   2016-07-04 17:00:00  1.25825      1.263882
# 4   2016-07-04 18:00:00  1.08900      1.282499
# ..                  ...      ...           ...
# 437 2016-07-22 19:00:00  1.26675      1.366500
# 438 2016-07-22 20:00:00  1.07250      1.266750
# 439 2016-07-22 21:00:00  0.98050      1.072500
# 440 2016-07-22 22:00:00  0.91125      0.980500
# 441 2016-07-22 23:00:00  0.45300      0.911250
#
# [442 rows x 3 columns]

# %%
#Calculate rmse
# Root Mean Square Error (RMSE)
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math
rmse = np.sqrt(mean_squared_error(fd.DMA_468,fd.DMA_468_pred))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  0.225

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd.Date_time, fd.DMA_468, color='red', label='original')
plt.plot(fd.Date_time, fd.DMA_468_pred, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()
