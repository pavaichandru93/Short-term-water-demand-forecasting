# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib as mpl
from datetime import datetime
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, LeakyReLU,ReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation


mpl.rcParams['figure.figsize'] = (20, 15)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf 
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/dataframe_flow_variable_60min.csv")
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'])
data.rename( columns={'Unnamed: 0':'Date_time','225':'DMA_225'}, inplace=True )
data_DMA225 = data[['Date_time','DMA_225','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']]
data_DMA225_indexed = data_DMA225.set_index('Date_time')
data_DMA225_indexed[['DMA_225','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fb99ca5b650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99c9b9810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99ca5b250>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99c92fe50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99c8f21d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99c8a8510>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99c860850>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99c899b90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fb99c82f090>],
#       dtype=object)

# %%
# Making hourly data 
hourly_data = data_DMA225_indexed.resample('h').sum()
#hr = hourly_data.values
#Train and test split
split = 240
train = hourly_data[:-500]
test = hourly_data[-500:]

# %%
#Separate dates for future plotting
trainset = train.reset_index()
train_dates = pd.to_datetime(trainset['Date_time'])
len(train_dates)
# Out:
# 1708

# %%
#Variables for training
cols = list(train)[:10]
df_for_training = train[cols]

#LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
# normalize the dataset
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
df_for_training_scaled.shape
# Out:
# (1708, 9)

# %%
#Empty lists to be populated using formatted training data
trainX = []
trainY = []

n_future = 1   # Number of days we want to look into the future based on the past days.
n_past = 24  # Number of past days we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)
#In my example, my df_for_training_scaled has a shape (12823, 5)
#12823 refers to the number of data points and 5 refers to the columns (multi-variables).
for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))

trainX, trainY = np.array(trainX), np.array(trainY)
# Out:
# trainX shape == (1684, 24, 9).
# trainY shape == (1684, 1).

# %%
import tensorflow
model = Sequential()
model.add(LSTM(15, activation='relu',input_shape=(trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LeakyReLU(alpha=0.9)) 
model.add(Dropout(0.17))
#model.add(Dense(20))
model.add(Dense(60))
model.add(LeakyReLU(alpha=0.05))
model.add(LSTM(20,return_sequences=False))
model.add(LeakyReLU(alpha=0.9))
model.add(Dropout(0.2))
#10000005
model.add(Dense(trainY.shape[1]))
initial_learning_rate = 0.5
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000035,
    decay_rate=1.09,
    #decay_rate= 0.00001,
    staircase=True)
opt = tf.keras.optimizers.Adam(lr_schedule, epsilon=1.25, beta_1=0.19,beta_2=0.53)
model.compile(optimizer=opt, loss='mae')
model.summary()


# fit the model
history = model.fit(trainX, trainY, epochs=50, batch_size=1000, validation_split=0.2, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 15)            1500
#
#  leaky_re_lu (LeakyReLU)     (None, 24, 15)            0
#
#  dropout (Dropout)           (None, 24, 15)            0
#
#  dense (Dense)               (None, 24, 60)            960
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 24, 60)            0
#
#  lstm_1 (LSTM)               (None, 20)                6480
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 20)                0
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 8,961
# Trainable params: 8,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2/2 [==============================] - 4s 783ms/step - loss: 0.8991 - val_loss: 0.8005
# Epoch 2/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.8563 - val_loss: 0.7887
# Epoch 3/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.8383 - val_loss: 0.7711
# Epoch 4/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.8157 - val_loss: 0.7575
# Epoch 5/50
# 2/2 [==============================] - 0s 93ms/step - loss: 0.7864 - val_loss: 0.6870
# Epoch 6/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.7384 - val_loss: 0.6425
# Epoch 7/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.8035 - val_loss: 0.6234
# Epoch 8/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6864 - val_loss: 0.6118
# Epoch 9/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.6199 - val_loss: 0.5201
# Epoch 10/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.5415 - val_loss: 0.5827
# Epoch 11/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.6483 - val_loss: 0.6376
# Epoch 12/50
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6218 - val_loss: 0.4469
# Epoch 13/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.5122 - val_loss: 0.4141
# Epoch 14/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.4758 - val_loss: 0.4028
# Epoch 15/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4617 - val_loss: 0.3833
# Epoch 16/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.4582 - val_loss: 0.3631
# Epoch 17/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.4382 - val_loss: 0.3656
# Epoch 18/50
# 2/2 [==============================] - 0s 108ms/step - loss: 0.4425 - val_loss: 0.3928
# Epoch 19/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.4644 - val_loss: 0.3910
# Epoch 20/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.4592 - val_loss: 0.3432
# Epoch 21/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3940 - val_loss: 0.3276
# Epoch 22/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.3961 - val_loss: 0.3562
# Epoch 23/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.4102 - val_loss: 0.3680
# Epoch 24/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4269 - val_loss: 0.4297
# Epoch 25/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.4562 - val_loss: 0.3373
# Epoch 26/50
# 2/2 [==============================] - 0s 103ms/step - loss: 0.3984 - val_loss: 0.3272
# Epoch 27/50
# 2/2 [==============================] - 0s 106ms/step - loss: 0.3945 - val_loss: 0.3113
# Epoch 28/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.3782 - val_loss: 0.3034
# Epoch 29/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.3761 - val_loss: 0.3003
# Epoch 30/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.3555 - val_loss: 0.3115
# Epoch 31/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.3577 - val_loss: 0.3277
# Epoch 32/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.3868 - val_loss: 0.3959
# Epoch 33/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.4228 - val_loss: 0.3467
# Epoch 34/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.4019 - val_loss: 0.2872
# Epoch 35/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.3560 - val_loss: 0.2948
# Epoch 36/50
# 2/2 [==============================] - 0s 109ms/step - loss: 0.3517 - val_loss: 0.2936
# Epoch 37/50
# 2/2 [==============================] - 0s 100ms/step - loss: 0.3520 - val_loss: 0.3284
# Epoch 38/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.3962 - val_loss: 0.3275
# Epoch 39/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.3633 - val_loss: 0.3107
# Epoch 40/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.3566 - val_loss: 0.3871
# Epoch 41/50
# 2/2 [==============================] - 0s 114ms/step - loss: 0.4263 - val_loss: 0.3058
# Epoch 42/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.3534 - val_loss: 0.3263
# Epoch 43/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.3764 - val_loss: 0.3151
# Epoch 44/50
# 2/2 [==============================] - 0s 93ms/step - loss: 0.3794 - val_loss: 0.3166
# Epoch 45/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.3583 - val_loss: 0.2828
# Epoch 46/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.3496 - val_loss: 0.2805
# Epoch 47/50
# 2/2 [==============================] - 0s 96ms/step - loss: 0.3406 - val_loss: 0.2835
# Epoch 48/50
# 2/2 [==============================] - 0s 99ms/step - loss: 0.3315 - val_loss: 0.3725
# Epoch 49/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.3709 - val_loss: 0.3690
# Epoch 50/50
# 2/2 [==============================] - 0s 116ms/step - loss: 0.3902 - val_loss: 0.4227

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(history,'LSTM')

# %%
n_past = 24
n_days_for_prediction=524  #let us predict past 15 days

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq='1H').tolist()

#Make prediction
prediction = model.predict(trainX[-n_days_for_prediction:])
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
# Convert timestamp to date
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i)
    
df_forecast = pd.DataFrame({'Date_time':np.array(forecast_dates), 'DMA_225_pred':y_pred_future})
df_forecast['Date_time']=pd.to_datetime(df_forecast['Date_time'])

# making predicted df

df1=df_forecast[24:]
df1= df1.reset_index()
df1= df1.drop(['index'], axis=1)

# test dataset

t1 = test.reset_index()
t1 = t1[['Date_time','DMA_225']]

# final df
fd=pd.merge(t1, df1, on="Date_time")

# %%
#Calculate rmse
# Root Mean Square Error (RMSE)
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math
rmse = np.sqrt(mean_squared_error(fd.DMA_225,fd.DMA_225_pred))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  1.428

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd.Date_time, fd.DMA_225, color='red', label='original')
plt.plot(fd.Date_time, fd.DMA_225_pred, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()
