# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.2-cp37-cp37m-manylinux1_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 7.2 MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 12.3 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.2 statsmodels-0.12.2

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import numpy as np
from datetime import datetime
import plotly.express as px
import itertools
from pylab import rcParams
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False

from math import sqrt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import kpss
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout

import math
from sklearn.metrics import mean_squared_error

np.random.seed(42)
tf.random.set_seed(42)

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls'/content/gdrive/My Drive/Thesis'
# Out:
# dataframe_dma_flow_1D.csv       dataframe_flow_variable_60min.csv
# dataframe_dma_flow_60min.csv    DMA_225.csv
# dataframe_flow_1D.csv           DMA_468.csv
# dataframe_flow_variable_1D.csv  persistence_results.pkl

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/DMA_468.csv")
data['Date-time'] = pd.to_datetime(data['Date-time'], dayfirst=True, errors='coerce')
data.rename( columns={'Flow':'DMA_468','Date-time':'Date_time'}, inplace=True )
data_DMA468 = data[['Date_time','DMA_468']]

# %%
figure = px.line(data_DMA468,x="Date_time",y="DMA_468",title="DMA_468 with slider")
figure.update_xaxes(rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="12m",
                     step="month",
                     stepmode="backward"),
                dict(count=2,
                     label="8m",
                     step="month",
                     stepmode="backward"),
                dict(count=3,
                     label="4m",
                     step="month",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        )
    )
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2f83aaf7-e2ac-4112-8546-b856ade2530e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f83aaf7-e2ac-4112-8546-b856ade2530e")) {
#                     Plotly.newPlot(
#                         '2f83aaf7-e2ac-4112-8546-b856ade2530e',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Date_time=%{x}<br>DMA_468=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2016-04-01T00:00:00", "2016-04-01T00:15:00", "2016-04-01T00:30:00", "2016-04-01T00:45:00", "2016-04-01T01:00:00", "2016-04-01T01:15:00", "2016-04-01T01:30:00", "2016-04-01T01:45:00", "2016-04-01T02:00:00", "2016-04-01T02:15:00", "2016-04-01T02:30:00", "2016-04-01T02:45:00", "2016-04-01T03:00:00", "2016-04-01T03:15:00", "2016-04-01T03:30:00", "2016-04-01T03:45:00", "2016-04-01T04:00:00", "2016-04-01T04:15:00", "2016-04-01T04:30:00", "2016-04-01T04:45:00", "2016-04-01T05:00:00", "2016-04-01T05:15:00", "2016-04-01T05:30:00", "2016-04-01T05:45:00", "2016-04-01T06:00:00", "2016-04-01T06:15:00", "2016-04-01T06:30:00", "2016-04-01T06:45:00", "2016-04-01T07:00:00", "2016-04-01T07:15:00", "2016-04-01T07:30:00", "2016-04-01T07:45:00", "2016-04-01T08:00:00", "2016-04-01T08:15:00", "2016-04-01T08:30:00", "2016-04-01T08:45:00", "2016-04-01T09:00:00", "2016-04-01T09:15:00", "2016-04-01T09:30:00", "2016-04-01T09:45:00", "2016-04-01T10:00:00", "2016-04-01T10:15:00", "2016-04-01T10:30:00", "2016-04-01T10:45:00", "2016-04-01T11:00:00", "2016-04-01T11:15:00", "2016-04-01T11:30:00", "2016-04-01T11:45:00", "2016-04-01T12:00:00", "2016-04-01T12:15:00", "2016-04-01T12:30:00", "2016-04-01T12:45:00", "2016-04-01T13:00:00", "2016-04-01T13:15:00", "2016-04-01T13:30:00", "2016-04-01T13:45:00", "2016-04-01T14:00:00", "2016-04-01T14:15:00", "2016-04-01T14:30:00", "2016-04-01T14:45:00", "2016-04-01T15:00:00", "2016-04-01T15:15:00", "2016-04-01T15:30:00", "2016-04-01T15:45:00", "2016-04-01T16:00:00", "2016-04-01T16:15:00", "2016-04-01T16:30:00", "2016-04-01T16:45:00", "2016-04-01T17:00:00", "2016-04-01T17:15:00", "2016-04-01T
plot(grid=True)
plt.figure(figsize=(22,10))

# %%
# Augmented Dickey-Fuller test
#Null Hypothesis (H0): If failed to be rejected, meaning it is non-stationary. It has some time dependent structure.
#Alternate Hypothesis (H1): The null hypothesis is rejected;  meaning it is stationary. It does not have time-dependent structure.

ADF_Check_Stationary = adfuller(daily_data)
print('ADF Statistic: %f' % ADF_Check_Stationary[0])
print('p-value: %f' % ADF_Check_Stationary[1])
print('Critical Values:')
for key, value in ADF_Check_Stationary[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.854313
# p-value: 0.000000
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571

# %% [markdown]
# Observation :
#
# 1.The ADF statistic value of -5.8. The more negative this statistic, the more likely we are to reject the null hypothesis (we have a stationary dataset).
#
# 2.p value - 0.000000 < 0.05 ; Data is stationary

# %%
#Kwiatkowski-Phillips-Schmidt-Shin test
#Null Hypothesis (H0): stationary.
#Alternate Hypothesis (H1): non-stationary

KPSS_Check_Stationary = kpss(daily_data)
KPSS_Check_Stationary
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1875: FutureWarning:
#
# The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1911: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
# (0.14839409550096347,
#  0.1,
#  17,
#  {'1%': 0.739, '10%': 0.347, '2.5%': 0.574, '5%': 0.463})

# %% [markdown]
# Observation : 1.The ADF statistic value of 0.14. The positive value is statistic, and hence we have a stationary dataset

# %%
res=sm.tsa.seasonal_decompose(daily_data,period=7)
fig = res.plot()
fig.set_figheight(10)
fig.set_figwidth(18)
plt.show()

# %% [markdown]
# Baseline model : Persistence model

# %%
# Making a df
Original = daily_data["DMA_468"].to_frame().rename(columns = {"DMA_468": "Original" })
Forecast  = daily_data["DMA_468"].to_frame().shift(1).rename(columns = {"DMA_468": "Forecast" })
baseline = pd.concat([Original,Forecast],axis=1)
final = baseline[1:]#there is no prediction for first row due to shifting.
# Calculate the RMSE
rmse = np.sqrt(mean_squared_error(final.Original, final.Forecast))
rmse = round(rmse, 3)
print (" The root mean square value on dataset: ",rmse)
# Out:
#  The root mean square value on dataset:  8.082

# %%
baseline_model = final[['Forecast']]
baseline_model.plot(grid=True)
plt.figure(figsize=(22,10))

# %%
final.plot(figsize=(12,8))

# %%
baseline_graph = final[-110:]
rmse1 = np.sqrt(mean_squared_error(baseline_graph.Original, baseline_graph.Forecast))
rmse1 = round(rmse1, 3)
print (" The root mean square value on dataset using baseline model: ",rmse1)
baseline_graph.plot(figsize=(12,8))
# Out:
#  The root mean square value on dataset using baseline model:  8.057

# %% [markdown]
# Sarimax

# %%
# Getting best arima model 
p = d = q = range(0, 2)
pdq_cal = list(itertools.product(p, d, q))
# generation of different combinations of seasonal p, q and q triplets
pdq_seasonal = [(x[0], x[1], x[2], 7) for x in list(itertools.product(p, d, q))]
aic_bestvalue = np.inf
pdq_bestvalue = None
pdq_seasonal_best = None
tempmodel = None
for params in pdq_cal:   
    for seasonal_params in pdq_seasonal: 
        tempmodel = SARIMAX(daily_data['DMA_468'],order=params,seasonal_order = seasonal_params,enforce_invertibility=False,enforce_stationarity=False)
        results = tempmodel.fit(disp=False)
        if results.aic < aic_bestvalue:
            aic_bestvalue = results.aic
            pdq_bestvalue = params
            pdq_seasonal_best = seasonal_params
print("Best ARIMA with seasonality (SARIMAX) {} x {} model - AIC:{}".format(pdq_bestvalue,pdq_seasonal_best,aic_bestvalue))
# Out:
# Best ARIMA with seasonality (SARIMAX) (1, 0, 1) x (0, 1, 1, 7) model - AIC:2333.821275318386

# %%
daily_data.shape
# Out:
# (365, 1)

# %%
train_size = int(len(daily_data)*0.7)
train = daily_data[:train_size]
test = daily_data[train_size:]

# %%
train.head(2)
# Out:
#             DMA_468
# Date_time
# 2016-04-01   71.247
# 2016-04-02   64.973

# %%
test.head(2)
# Out:
#             DMA_468
# Date_time
# 2016-12-12   70.505
# 2016-12-13   77.813

# %%
# Training the model on the full dataset and predict last 24 hours output
model =  SARIMAX(daily_data,order = (1, 0, 1), 
                        seasonal_order =(0, 1, 1, 7),enforce_invertibility=False,
                             enforce_stationarity=False)
sarimax = model.fit()
sarimax.plot_diagnostics(figsize=(12, 12))
plt.show()

# %%
weekly_prediction = sarimax.get_prediction(start=pd.to_datetime('2016-12-12'), dynamic=False)
weekly_prediction_ci = weekly_prediction.conf_int()
ax = train['2016-04-01':].plot(label='observed')
weekly_prediction.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, figsize=(16, 5))
ax.fill_between(weekly_prediction_ci.index,
                weekly_prediction_ci.iloc[:, 0],
                weekly_prediction_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date_time')
ax.set_ylabel('DMA_468')
ax.set_title('DMA 468 weekly prediction')
plt.legend()
plt.show()

# %%
forecast_prediction = weekly_prediction.predicted_mean
forecast_prediction = forecast_prediction.to_frame()
fp=forecast_prediction.reset_index()
testset = test.reset_index()
fd=pd.merge(testset, fp, on="Date_time")

# %%
# Calculate rmse of original and predicted value
rmse = np.sqrt(mean_squared_error(fd.DMA_468,fd.predicted_mean))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  6.508

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd.Date_time, fd.DMA_468, color='red', label='original')
plt.plot(fd.Date_time, fd.predicted_mean, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()

# %% [markdown]
# #LSTM

# %%
dd = daily_data.values
train_size = int(len(dd)*0.7)
train_data = dd[:train_size]
test_data = dd[train_size:]

# %%
train_data.shape
# Out:
# (255, 1)

# %%
test_data.shape
# Out:
# (110, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.fit_transform(test_data)

# %%
def matrix_dataset(array_dataset, timesteps=1):
 mat_X, mat_Y = [], []
 for i in range(len(array_dataset)-timesteps-1):
  Z = i+timesteps
  m = array_dataset[i:Z, 0]
  mat_X.append(m)
  n = array_dataset[Z, 0]
  mat_Y.append(n)
 return np.array(mat_X), np.array( mat_Y)


look_back = 3
features = 1
X_train1, Y_train1 = matrix_dataset(train_scaled, look_back)
X_test1, Y_test1 = matrix_dataset(test_scaled, look_back)

# %%
X_train1 = X_train1.reshape((X_train1.shape[0],X_train1.shape[1],1))
X_test1 = X_test1.reshape( (X_test1.shape[0],X_test1.shape[1],1))

# %%
model = Sequential()
model.add(LSTM(25,input_shape=(3, 1)))
model.add(Dropout(0.20))
# model.add(Dense(80))
# model.add(Dropout(0.30))
model.add(Dense(7))
model.compile(loss='mean_squared_error', optimizer='adam')
#y=model.fit(X_train1,Y_train1, epochs=150, batch_size=2, validation_data=(X_test1,Y_test1), callbacks=[EarlyStopping(monitor='val_loss',patience=10)])
y=model.fit(X_train1,Y_train1, epochs=100, batch_size=1, validation_data=(X_test1,Y_test1))
# Out:
# Epoch 1/100
# 251/251 [==============================] - 2s 4ms/step - loss: 0.0218 - val_loss: 0.0165
# Epoch 2/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0159 - val_loss: 0.0159
# Epoch 3/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0154 - val_loss: 0.0175
# Epoch 4/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0162 - val_loss: 0.0167
# Epoch 5/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0153 - val_loss: 0.0150
# Epoch 6/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0146 - val_loss: 0.0174
# Epoch 7/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0148 - val_loss: 0.0168
# Epoch 8/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0139 - val_loss: 0.0149
# Epoch 9/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0142 - val_loss: 0.0155
# Epoch 10/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0141 - val_loss: 0.0161
# Epoch 11/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0138 - val_loss: 0.0150
# Epoch 12/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0147 - val_loss: 0.0147
# Epoch 13/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0138 - val_loss: 0.0171
# Epoch 14/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0138 - val_loss: 0.0147
# Epoch 15/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0140 - val_loss: 0.0156
# Epoch 16/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0139 - val_loss: 0.0147
# Epoch 17/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0134 - val_loss: 0.0148
# Epoch 18/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0136 - val_loss: 0.0150
# Epoch 19/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0129 - val_loss: 0.0143
# Epoch 20/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 21/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0133 - val_loss: 0.0136
# Epoch 22/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0135 - val_loss: 0.0150
# Epoch 23/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0128 - val_loss: 0.0161
# Epoch 24/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0129 - val_loss: 0.0156
# Epoch 25/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0125 - val_loss: 0.0142
# Epoch 26/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0135
# Epoch 27/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 28/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0128 - val_loss: 0.0136
# Epoch 29/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0127 - val_loss: 0.0155
# Epoch 30/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0125 - val_loss: 0.0131
# Epoch 31/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0130 - val_loss: 0.0130
# Epoch 32/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0125 - val_loss: 0.0129
# Epoch 33/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 34/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0124 - val_loss: 0.0133
# Epoch 35/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0124 - val_loss: 0.0128
# Epoch 36/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0125
# Epoch 37/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0125 - val_loss: 0.0128
# Epoch 38/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0125
# Epoch 39/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0123 - val_loss: 0.0132
# Epoch 40/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0126 - val_loss: 0.0130
# Epoch 41/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0127 - val_loss: 0.0131
# Epoch 42/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0125
# Epoch 43/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0137
# Epoch 44/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0123
# Epoch 45/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0119
# Epoch 46/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0123 - val_loss: 0.0127
# Epoch 47/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0129
# Epoch 48/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0125
# Epoch 49/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0120 - val_loss: 0.0128
# Epoch 50/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0129
# Epoch 51/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0123
# Epoch 52/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0123
# Epoch 53/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0123
# Epoch 54/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0126
# Epoch 55/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 56/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0120
# Epoch 57/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0122
# Epoch 58/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0121
# Epoch 59/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0121
# Epoch 60/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0120 - val_loss: 0.0128
# Epoch 61/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0130
# Epoch 62/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 63/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0120
# Epoch 64/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0120 - val_loss: 0.0118
# Epoch 65/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0126
# Epoch 66/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0121
# Epoch 67/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0127
# Epoch 68/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 69/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0118
# Epoch 70/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0122
# Epoch 71/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0123
# Epoch 72/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0112 - val_loss: 0.0122
# Epoch 73/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0124
# Epoch 74/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0128
# Epoch 75/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0120 - val_loss: 0.0121
# Epoch 76/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0125
# Epoch 77/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0122
# Epoch 78/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0112 - val_loss: 0.0124
# Epoch 79/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0123
# Epoch 80/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0114 - val_loss: 0.0120
# Epoch 81/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0113 - val_loss: 0.0127
# Epoch 82/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0123
# Epoch 83/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0115 - val_loss: 0.0126
# Epoch 84/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0119
# Epoch 85/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0122
# Epoch 86/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0118
# Epoch 87/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0125
# Epoch 88/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0113 - val_loss: 0.0120
# Epoch 89/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0121
# Epoch 90/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0118
# Epoch 91/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0113 - val_loss: 0.0129
# Epoch 92/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 93/100
# 251/251 [==============================] - 1s 2ms/step - loss: 0.0112 - val_loss: 0.0121
# Epoch 94/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0116
# Epoch 95/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0118
# Epoch 96/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0114 - val_loss: 0.0121
# Epoch 97/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 98/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0120
# Epoch 99/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0113 - val_loss: 0.0124
# Epoch 100/100
# 251/251 [==============================] - 1s 3ms/step - loss: 0.0115 - val_loss: 0.0118

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(y.history['loss'])
    plt.plot(y.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(y,'LSTM')

# %%
# Generate predictions
train_pred = model.predict(X_train1)
#evaluation = model.evaluate(x=X_test, y=y_test, verbose=1)
test_pred = model.predict(X_test1)

# %%
# Generate predictions
train_pred = model.predict(X_train1)
#evaluation = model.evaluate(x=X_test, y=y_test, verbose=1)
test_pred = model.predict(X_test1)

# %%
# De-standardising the output to original value
train_pred = scaler.inverse_transform(train_pred)
y_train = scaler.inverse_transform([Y_train1])
test_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform([Y_test1])
predictions = test_pred

# %%
# To make a dataframe of original and predicted value:
lstm_df=[]
for i in range (0, len(predictions)):
  lstm_df.append((predictions[i][0]))
final_data = pd.DataFrame((y_test[0]))
#final_data = pd.DataFrame((Y_test))
final_data.rename(columns = {0:'original_value'}, inplace = True)
final_data['predicted_value'] = lstm_df

# %%
testset = math.sqrt(mean_squared_error(final_data['original_value'], final_data['predicted_value']))
print("The RMSE prediction value on testset: ",testset)
# Out:
# The RMSE prediction value on testset:  6.398755045640059

# %%
final_df2= daily_data.reset_index()
# Comparing the forecasts with the actual values
yhat = [x[0] for x in model.predict(X_test1)]
y = [y for y in Y_test1]
# Creating the frame to store both predictions
days = final_df2[['Date_time']].values[-len(y):]
df = pd.DataFrame(days,columns = ['Date_time'])
result = pd.concat([df, final_data], axis=1, join='inner')
result.shape
# Out:
# (106, 3)

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(result.Date_time, result.original_value, color='red', label='original')
plt.plot(result.Date_time, result.predicted_value, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()
