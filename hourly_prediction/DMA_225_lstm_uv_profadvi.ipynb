# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import numpy as np
from datetime import datetime
import plotly.express as px
import itertools
from pylab import rcParams
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False

from math import sqrt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout

np.random.seed(42)
tf.random.set_seed(42)

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls'/content/gdrive/My Drive/Thesis'
# Out:
# dataframe_dma_flow_1D.csv       dataframe_flow_variable_60min.csv
# dataframe_dma_flow_60min.csv    DMA_225.csv
# dataframe_flow_1D.csv           DMA_468.csv
# dataframe_flow_variable_1D.csv  persistence_results.pkl

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/DMA_225.csv")
data['Date-time'] = pd.to_datetime(data['Date-time'], dayfirst=True, errors='coerce')
data.rename( columns={'Flow':'DMA_225','Date-time':'Date_time'}, inplace=True )
data_DMA225 = data[['Date_time','DMA_225']]

# %%
data_DMA225_indexed = data_DMA225.set_index('Date_time')

# Making hourly data 
hourly_data = data_DMA225_indexed.resample('h').sum()

hourly_data.isnull().sum().sum()
hourly_data.isna().sum().sum()
data_hourly = hourly_data.values

# %%
#Train and test split
#split = 1059
##train = data_hourly[:7008]

##test = data_hourly[7008:]

# %%
#Train and test split
split = 1059
train = data_hourly[:-1059]
test = data_hourly[-1059:]

# %%
train.shape
# Out:
# (7701, 1)

# %%
test.shape
# Out:
# (1059, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.fit_transform(test)

# %%
def data_preparation(array_dataset, look_back=1, future=1, index=0):
    features = array_dataset.shape[1]
    arr_X, arr_Y = [], []
    if len(array_dataset) - look_back <= 0:
        arr_X.append(array_dataset)
    else:
        for i in range(len(array_dataset) - look_back - future):
            arr_Y.append(array_dataset[(i + look_back), index])
            arr_X.append(array_dataset[i:(i + look_back)])
    arr_X, arr_Y = np.array(arr_X), np.array(arr_Y)
    arr_X = np.reshape(arr_X, (arr_X.shape[0], look_back, features))
    return arr_X, arr_Y

look_back = 24
features = 1
X_train, Y_train = data_preparation(train_scaled, look_back=24, future=24, index=0)
X_test, Y_test = data_preparation(test_scaled, look_back=24, future=24, index=0)

# %%
X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],1))
X_test = X_test.reshape( (X_test.shape[0],X_test.shape[1],1))

# %%
print('X_train shape:',X_train.shape)
print('Y_train shape:',Y_train.shape)
print('X_test shape:',X_test.shape)
print('Y_test shape:',Y_test.shape)
# Out:
# X_train shape: (7653, 24, 1)
# Y_train shape: (7653,)
# X_test shape: (1011, 24, 1)
# Y_test shape: (1011,)

# %%
model2 = tf.keras.Sequential()
model2.add(LSTM(80, input_shape=(look_back,features)))
#model2.add(Dropout(0.2))
#model2.add(LSTM(80));
model2.add(Dense(80))
model2.add(Dense(100))
#model2.add(Dense(150));
#model2.add(Dense(80))
model2.add(Dense(24))
optimizer = tf.keras.optimizers.Adam(lr=0.09,decay=0.90);
model2.compile(loss='mae', optimizer=optimizer, metrics=['accuracy'])
#history=model.fit(X_train1, Y_train1, validation_data=(X_test1,Y_test1),shuffle=False, epochs=100, batch_size=1, verbose=2)
history2=model2.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=300,batch_size=300)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
# Epoch 1/300
# 26/26 [==============================] - 5s 102ms/step - loss: 6.9234 - accuracy: 0.0000e+00 - val_loss: 0.8920 - val_accuracy: 9.8912e-04
# Epoch 2/300
# 26/26 [==============================] - 2s 88ms/step - loss: 0.2498 - accuracy: 1.3067e-04 - val_loss: 0.7865 - val_accuracy: 9.8912e-04
# Epoch 3/300
# 26/26 [==============================] - 2s 74ms/step - loss: 0.0639 - accuracy: 0.0000e+00 - val_loss: 0.5710 - val_accuracy: 9.8912e-04
# Epoch 4/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0371 - accuracy: 0.0000e+00 - val_loss: 0.4268 - val_accuracy: 9.8912e-04
# Epoch 5/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0302 - accuracy: 0.0000e+00 - val_loss: 0.3550 - val_accuracy: 9.8912e-04
# Epoch 6/300
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0278 - accuracy: 0.0000e+00 - val_loss: 0.3132 - val_accuracy: 9.8912e-04
# Epoch 7/300
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0252 - accuracy: 0.0000e+00 - val_loss: 0.2920 - val_accuracy: 9.8912e-04
# Epoch 8/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0241 - accuracy: 0.0000e+00 - val_loss: 0.2730 - val_accuracy: 9.8912e-04
# Epoch 9/300
# 26/26 [==============================] - 2s 74ms/step - loss: 0.0242 - accuracy: 0.0000e+00 - val_loss: 0.2652 - val_accuracy: 9.8912e-04
# Epoch 10/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0227 - accuracy: 0.0000e+00 - val_loss: 0.2523 - val_accuracy: 9.8912e-04
# Epoch 11/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0228 - accuracy: 0.0000e+00 - val_loss: 0.2461 - val_accuracy: 9.8912e-04
# Epoch 12/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0221 - accuracy: 0.0000e+00 - val_loss: 0.2365 - val_accuracy: 0.0000e+00
# Epoch 13/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0212 - accuracy: 0.0000e+00 - val_loss: 0.2301 - val_accuracy: 0.0000e+00
# Epoch 14/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0209 - accuracy: 0.0000e+00 - val_loss: 0.2255 - val_accuracy: 0.0000e+00
# Epoch 15/300
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0206 - accuracy: 0.0000e+00 - val_loss: 0.2178 - val_accuracy: 0.0000e+00
# Epoch 16/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0200 - accuracy: 0.0000e+00 - val_loss: 0.2124 - val_accuracy: 0.0000e+00
# Epoch 17/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0197 - accuracy: 0.0000e+00 - val_loss: 0.2079 - val_accuracy: 0.0000e+00
# Epoch 18/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0195 - accuracy: 0.0000e+00 - val_loss: 0.2034 - val_accuracy: 0.0000e+00
# Epoch 19/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0192 - accuracy: 0.0000e+00 - val_loss: 0.1982 - val_accuracy: 0.0000e+00
# Epoch 20/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0189 - accuracy: 0.0000e+00 - val_loss: 0.1952 - val_accuracy: 0.0000e+00
# Epoch 21/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0184 - accuracy: 0.0000e+00 - val_loss: 0.1893 - val_accuracy: 0.0000e+00
# Epoch 22/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0181 - accuracy: 0.0000e+00 - val_loss: 0.1866 - val_accuracy: 0.0000e+00
# Epoch 23/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0182 - accuracy: 0.0000e+00 - val_loss: 0.1828 - val_accuracy: 0.0000e+00
# Epoch 24/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0178 - accuracy: 0.0000e+00 - val_loss: 0.1788 - val_accuracy: 0.0000e+00
# Epoch 25/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0176 - accuracy: 0.0000e+00 - val_loss: 0.1758 - val_accuracy: 0.0000e+00
# Epoch 26/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0172 - accuracy: 0.0000e+00 - val_loss: 0.1735 - val_accuracy: 0.0000e+00
# Epoch 27/300
# 26/26 [==============================] - 2s 75ms/step - loss: 0.0169 - accuracy: 0.0000e+00 - val_loss: 0.1694 - val_accuracy: 0.0000e+00
# Epoch 28/300
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0170 - accuracy: 0.0000e+00 - val_loss: 0.1670 - val_accuracy: 0.0000e+00
# Epoch 29/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0165 - accuracy: 0.0000e+00 - val_loss: 0.1638 - val_accuracy: 0.0000e+00
# Epoch 30/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0163 - accuracy: 0.0000e+00 - val_loss: 0.1611 - val_accuracy: 0.0000e+00
# Epoch 31/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0158 - accuracy: 0.0000e+00 - val_loss: 0.1581 - val_accuracy: 0.0000e+00
# Epoch 32/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0157 - accuracy: 0.0000e+00 - val_loss: 0.1560 - val_accuracy: 0.0000e+00
# Epoch 33/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0155 - accuracy: 0.0000e+00 - val_loss: 0.1533 - val_accuracy: 0.0000e+00
# Epoch 34/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0154 - accuracy: 0.0000e+00 - val_loss: 0.1512 - val_accuracy: 0.0000e+00
# Epoch 35/300
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0153 - accuracy: 0.0000e+00 - val_loss: 0.1487 - val_accuracy: 0.0000e+00
# Epoch 36/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.1472 - val_accuracy: 0.0000e+00
# Epoch 37/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0157 - accuracy: 0.0000e+00 - val_loss: 0.1450 - val_accuracy: 0.0000e+00
# Epoch 38/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0147 - accuracy: 0.0000e+00 - val_loss: 0.1427 - val_accuracy: 0.0000e+00
# Epoch 39/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0144 - accuracy: 0.0000e+00 - val_loss: 0.1405 - val_accuracy: 0.0000e+00
# Epoch 40/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0144 - accuracy: 0.0000e+00 - val_loss: 0.1381 - val_accuracy: 0.0000e+00
# Epoch 41/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0142 - accuracy: 0.0000e+00 - val_loss: 0.1368 - val_accuracy: 0.0000e+00
# Epoch 42/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0142 - accuracy: 0.0000e+00 - val_loss: 0.1350 - val_accuracy: 0.0000e+00
# Epoch 43/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0139 - accuracy: 0.0000e+00 - val_loss: 0.1332 - val_accuracy: 0.0000e+00
# Epoch 44/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0138 - accuracy: 0.0000e+00 - val_loss: 0.1312 - val_accuracy: 0.0000e+00
# Epoch 45/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0136 - accuracy: 0.0000e+00 - val_loss: 0.1298 - val_accuracy: 0.0000e+00
# Epoch 46/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0135 - accuracy: 0.0000e+00 - val_loss: 0.1281 - val_accuracy: 0.0000e+00
# Epoch 47/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0135 - accuracy: 0.0000e+00 - val_loss: 0.1265 - val_accuracy: 0.0000e+00
# Epoch 48/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0135 - accuracy: 0.0000e+00 - val_loss: 0.1250 - val_accuracy: 0.0000e+00
# Epoch 49/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0133 - accuracy: 0.0000e+00 - val_loss: 0.1235 - val_accuracy: 0.0000e+00
# Epoch 50/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0131 - accuracy: 0.0000e+00 - val_loss: 0.1219 - val_accuracy: 0.0000e+00
# Epoch 51/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0132 - accuracy: 0.0000e+00 - val_loss: 0.1203 - val_accuracy: 0.0000e+00
# Epoch 52/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0135 - accuracy: 0.0000e+00 - val_loss: 0.1194 - val_accuracy: 0.0000e+00
# Epoch 53/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0130 - accuracy: 0.0000e+00 - val_loss: 0.1179 - val_accuracy: 0.0000e+00
# Epoch 54/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0126 - accuracy: 0.0000e+00 - val_loss: 0.1167 - val_accuracy: 0.0000e+00
# Epoch 55/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0125 - accuracy: 0.0000e+00 - val_loss: 0.1156 - val_accuracy: 0.0000e+00
# Epoch 56/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0124 - accuracy: 0.0000e+00 - val_loss: 0.1141 - val_accuracy: 0.0000e+00
# Epoch 57/300
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0131 - accuracy: 0.0000e+00 - val_loss: 0.1129 - val_accuracy: 0.0000e+00
# Epoch 58/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0123 - accuracy: 0.0000e+00 - val_loss: 0.1117 - val_accuracy: 0.0000e+00
# Epoch 59/300
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.1106 - val_accuracy: 0.0000e+00
# Epoch 60/300
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.1095 - val_accuracy: 9.8912e-04
# Epoch 61/300
# 26/26 [==============================] - 2s 75ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.1083 - val_accuracy: 9.8912e-04
# Epoch 62/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.1073 - val_accuracy: 9.8912e-04
# Epoch 63/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.1060 - val_accuracy: 9.8912e-04
# Epoch 64/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.1051 - val_accuracy: 9.8912e-04
# Epoch 65/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.1039 - val_accuracy: 9.8912e-04
# Epoch 66/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.1032 - val_accuracy: 9.8912e-04
# Epoch 67/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.1020 - val_accuracy: 9.8912e-04
# Epoch 68/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.1008 - val_accuracy: 9.8912e-04
# Epoch 69/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.1001 - val_accuracy: 9.8912e-04
# Epoch 70/300
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0993 - val_accuracy: 9.8912e-04
# Epoch 71/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0983 - val_accuracy: 9.8912e-04
# Epoch 72/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0977 - val_accuracy: 9.8912e-04
# Epoch 73/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0968 - val_accuracy: 9.8912e-04
# Epoch 74/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0958 - val_accuracy: 9.8912e-04
# Epoch 75/300
# 26/26 [==============================] - 2s 75ms/step - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0949 - val_accuracy: 9.8912e-04
# Epoch 76/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0941 - val_accuracy: 9.8912e-04
# Epoch 77/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0933 - val_accuracy: 9.8912e-04
# Epoch 78/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 9.8912e-04
# Epoch 79/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0917 - val_accuracy: 9.8912e-04
# Epoch 80/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0911 - val_accuracy: 9.8912e-04
# Epoch 81/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0903 - val_accuracy: 0.0000e+00
# Epoch 82/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0896 - val_accuracy: 0.0000e+00
# Epoch 83/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0887 - val_accuracy: 0.0000e+00
# Epoch 84/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0881 - val_accuracy: 0.0000e+00
# Epoch 85/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0874 - val_accuracy: 0.0000e+00
# Epoch 86/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0869 - val_accuracy: 0.0000e+00
# Epoch 87/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0859 - val_accuracy: 0.0000e+00
# Epoch 88/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0855 - val_accuracy: 0.0000e+00
# Epoch 89/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0848 - val_accuracy: 0.0000e+00
# Epoch 90/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0841 - val_accuracy: 0.0000e+00
# Epoch 91/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0834 - val_accuracy: 0.0000e+00
# Epoch 92/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0827 - val_accuracy: 0.0000e+00
# Epoch 93/300
# 26/26 [==============================] - 2s 76ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0821 - val_accuracy: 0.0000e+00
# Epoch 94/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0816 - val_accuracy: 0.0000e+00
# Epoch 95/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0811 - val_accuracy: 0.0000e+00
# Epoch 96/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0804 - val_accuracy: 0.0000e+00
# Epoch 97/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0797 - val_accuracy: 0.0000e+00
# Epoch 98/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0794 - val_accuracy: 0.0000e+00
# Epoch 99/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0786 - val_accuracy: 0.0000e+00
# Epoch 100/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0780 - val_accuracy: 0.0000e+00
# Epoch 101/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0774 - val_accuracy: 0.0000e+00
# Epoch 102/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0097 - accuracy: 0.0000e+00 - val_loss: 0.0769 - val_accuracy: 0.0000e+00
# Epoch 103/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0763 - val_accuracy: 0.0000e+00
# Epoch 104/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0758 - val_accuracy: 0.0000e+00
# Epoch 105/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0750 - val_accuracy: 0.0000e+00
# Epoch 106/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0746 - val_accuracy: 0.0000e+00
# Epoch 107/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 108/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0093 - accuracy: 0.0000e+00 - val_loss: 0.0735 - val_accuracy: 0.0000e+00
# Epoch 109/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0730 - val_accuracy: 0.0000e+00
# Epoch 110/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0094 - accuracy: 0.0000e+00 - val_loss: 0.0726 - val_accuracy: 0.0000e+00
# Epoch 111/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0718 - val_accuracy: 0.0000e+00
# Epoch 112/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0716 - val_accuracy: 0.0000e+00
# Epoch 113/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0710 - val_accuracy: 0.0000e+00
# Epoch 114/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0704 - val_accuracy: 0.0000e+00
# Epoch 115/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0701 - val_accuracy: 0.0000e+00
# Epoch 116/300
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0696 - val_accuracy: 0.0000e+00
# Epoch 117/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0693 - val_accuracy: 0.0000e+00
# Epoch 118/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0687 - val_accuracy: 0.0000e+00
# Epoch 119/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0682 - val_accuracy: 0.0000e+00
# Epoch 120/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0679 - val_accuracy: 0.0000e+00
# Epoch 121/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0675 - val_accuracy: 0.0000e+00
# Epoch 122/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0671 - val_accuracy: 0.0000e+00
# Epoch 123/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0668 - val_accuracy: 0.0000e+00
# Epoch 124/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0662 - val_accuracy: 0.0000e+00
# Epoch 125/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0659 - val_accuracy: 0.0000e+00
# Epoch 126/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0658 - val_accuracy: 0.0000e+00
# Epoch 127/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0655 - val_accuracy: 0.0000e+00
# Epoch 128/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0652 - val_accuracy: 0.0000e+00
# Epoch 129/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0649 - val_accuracy: 0.0000e+00
# Epoch 130/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0646 - val_accuracy: 0.0000e+00
# Epoch 131/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0644 - val_accuracy: 0.0000e+00
# Epoch 132/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0642 - val_accuracy: 0.0000e+00
# Epoch 133/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0641 - val_accuracy: 0.0000e+00
# Epoch 134/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0638 - val_accuracy: 0.0000e+00
# Epoch 135/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0636 - val_accuracy: 0.0000e+00
# Epoch 136/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0634 - val_accuracy: 0.0000e+00
# Epoch 137/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0632 - val_accuracy: 0.0000e+00
# Epoch 138/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0631 - val_accuracy: 0.0000e+00
# Epoch 139/300
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0632 - val_accuracy: 0.0000e+00
# Epoch 140/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0631 - val_accuracy: 0.0000e+00
# Epoch 141/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0629 - val_accuracy: 0.0000e+00
# Epoch 142/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0626 - val_accuracy: 0.0000e+00
# Epoch 143/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0626 - val_accuracy: 0.0000e+00
# Epoch 144/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0623 - val_accuracy: 0.0000e+00
# Epoch 145/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0623 - val_accuracy: 0.0000e+00
# Epoch 146/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0621 - val_accuracy: 0.0000e+00
# Epoch 147/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0622 - val_accuracy: 0.0000e+00
# Epoch 148/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0619 - val_accuracy: 0.0000e+00
# Epoch 149/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0622 - val_accuracy: 0.0000e+00
# Epoch 150/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0619 - val_accuracy: 0.0000e+00
# Epoch 151/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0619 - val_accuracy: 0.0000e+00
# Epoch 152/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0616 - val_accuracy: 0.0000e+00
# Epoch 153/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0085 - accuracy: 0.0000e+00 - val_loss: 0.0616 - val_accuracy: 0.0000e+00
# Epoch 154/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0086 - accuracy: 0.0000e+00 - val_loss: 0.0616 - val_accuracy: 0.0000e+00
# Epoch 155/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0615 - val_accuracy: 0.0000e+00
# Epoch 156/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0615 - val_accuracy: 0.0000e+00
# Epoch 157/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0613 - val_accuracy: 0.0000e+00
# Epoch 158/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0613 - val_accuracy: 0.0000e+00
# Epoch 159/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0611 - val_accuracy: 0.0000e+00
# Epoch 160/300
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0612 - val_accuracy: 0.0000e+00
# Epoch 161/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0612 - val_accuracy: 0.0000e+00
# Epoch 162/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0609 - val_accuracy: 0.0000e+00
# Epoch 163/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0611 - val_accuracy: 0.0000e+00
# Epoch 164/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0610 - val_accuracy: 0.0000e+00
# Epoch 165/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0608 - val_accuracy: 0.0000e+00
# Epoch 166/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0607 - val_accuracy: 0.0000e+00
# Epoch 167/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0607 - val_accuracy: 0.0000e+00
# Epoch 168/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00
# Epoch 169/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0608 - val_accuracy: 0.0000e+00
# Epoch 170/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00
# Epoch 171/300
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0606 - val_accuracy: 0.0000e+00
# Epoch 172/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 173/300
# 26/26 [==============================] - 2s 77ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 174/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 175/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0603 - val_accuracy: 0.0000e+00
# Epoch 176/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 177/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0602 - val_accuracy: 0.0000e+00
# Epoch 178/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 179/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0601 - val_accuracy: 0.0000e+00
# Epoch 180/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 181/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 182/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0600 - val_accuracy: 0.0000e+00
# Epoch 183/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 184/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0599 - val_accuracy: 0.0000e+00
# Epoch 185/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 186/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 187/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 188/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0597 - val_accuracy: 0.0000e+00
# Epoch 189/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 190/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0596 - val_accuracy: 0.0000e+00
# Epoch 191/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 192/300
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0595 - val_accuracy: 0.0000e+00
# Epoch 193/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 194/300
# 26/26 [==============================] - 2s 78ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 195/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 196/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 197/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 198/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0592 - val_accuracy: 0.0000e+00
# Epoch 199/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 200/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 201/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 202/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 203/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 204/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 205/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0589 - val_accuracy: 0.0000e+00
# Epoch 206/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 207/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0082 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 208/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0588 - val_accuracy: 0.0000e+00
# Epoch 209/300
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 210/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 211/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 212/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0586 - val_accuracy: 0.0000e+00
# Epoch 213/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 214/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 215/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 216/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0584 - val_accuracy: 0.0000e+00
# Epoch 217/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 218/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 219/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 220/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 221/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 222/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 223/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 224/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 225/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 226/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 227/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 228/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 229/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 230/300
# 26/26 [==============================] - 2s 79ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 231/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 232/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 233/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 234/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 235/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 236/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 237/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 238/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 239/300
# 26/26 [==============================] - 2s 91ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 240/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 241/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 242/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 243/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 244/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 245/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 246/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0574 - val_accuracy: 0.0000e+00
# Epoch 247/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0573 - val_accuracy: 0.0000e+00
# Epoch 248/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 249/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0572 - val_accuracy: 0.0000e+00
# Epoch 250/300
# 26/26 [==============================] - 2s 88ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0571 - val_accuracy: 0.0000e+00
# Epoch 251/300
# 26/26 [==============================] - 2s 80ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 252/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0570 - val_accuracy: 0.0000e+00
# Epoch 253/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 254/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 255/300
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 256/300
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0569 - val_accuracy: 0.0000e+00
# Epoch 257/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 258/300
# 26/26 [==============================] - 2s 84ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 259/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 260/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0568 - val_accuracy: 0.0000e+00
# Epoch 261/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 262/300
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 263/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0566 - val_accuracy: 0.0000e+00
# Epoch 264/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 265/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 266/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0567 - val_accuracy: 0.0000e+00
# Epoch 267/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 268/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0565 - val_accuracy: 0.0000e+00
# Epoch 269/300
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0564 - val_accuracy: 0.0000e+00
# Epoch 270/300
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0564 - val_accuracy: 0.0000e+00
# Epoch 271/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0563 - val_accuracy: 0.0000e+00
# Epoch 272/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0563 - val_accuracy: 0.0000e+00
# Epoch 273/300
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0078 - accuracy: 0.0000e+00 - val_loss: 0.0564 - val_accuracy: 0.0000e+00
# Epoch 274/300
# 26/26 [==============================] - 2s 94ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0563 - val_accuracy: 0.0000e+00
# Epoch 275/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0562 - val_accuracy: 0.0000e+00
# Epoch 276/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0563 - val_accuracy: 0.0000e+00
# Epoch 277/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0562 - val_accuracy: 0.0000e+00
# Epoch 278/300
# 26/26 [==============================] - 2s 89ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0561 - val_accuracy: 0.0000e+00
# Epoch 279/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0561 - val_accuracy: 0.0000e+00
# Epoch 280/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0561 - val_accuracy: 0.0000e+00
# Epoch 281/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0562 - val_accuracy: 0.0000e+00
# Epoch 282/300
# 26/26 [==============================] - 2s 95ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0561 - val_accuracy: 0.0000e+00
# Epoch 283/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0561 - val_accuracy: 0.0000e+00
# Epoch 284/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0560 - val_accuracy: 0.0000e+00
# Epoch 285/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0560 - val_accuracy: 0.0000e+00
# Epoch 286/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0559 - val_accuracy: 0.0000e+00
# Epoch 287/300
# 26/26 [==============================] - 2s 83ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0560 - val_accuracy: 0.0000e+00
# Epoch 288/300
# 26/26 [==============================] - 2s 92ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0559 - val_accuracy: 0.0000e+00
# Epoch 289/300
# 26/26 [==============================] - 2s 85ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0559 - val_accuracy: 0.0000e+00
# Epoch 290/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0559 - val_accuracy: 0.0000e+00
# Epoch 291/300
# 26/26 [==============================] - 2s 93ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0558 - val_accuracy: 0.0000e+00
# Epoch 292/300
# 26/26 [==============================] - 2s 81ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0558 - val_accuracy: 0.0000e+00
# Epoch 293/300
# 26/26 [==============================] - 2s 82ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0557 - val_accuracy: 0.0000e+00
# Epoch 294/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0557 - val_accuracy: 0.0000e+00
# Epoch 295/300
# 26/26 [==============================] - 2s 87ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0557 - val_accuracy: 0.0000e+00
# Epoch 296/300
# 26/26 [==============================] - 3s 98ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0556 - val_accuracy: 0.0000e+00
# Epoch 297/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0557 - val_accuracy: 0.0000e+00
# Epoch 298/300
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0556 - val_accuracy: 0.0000e+00
# Epoch 299/300
# 26/26 [==============================] - 2s 86ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0556 - val_accuracy: 0.0000e+00
# Epoch 300/300
# 26/26 [==============================] - 2s 90ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0556 - val_accuracy: 0.0000e+00

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history2.history['loss'])
    plt.plot(history2.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(history2,'LSTM')

# %%
# Generate predictions
train_pred = model2.predict(X_train)
#evaluation = model.evaluate(x=X_test, y=y_test, verbose=1)
test_pred = model2.predict(X_test)

# %%
# De-standardising the output to original value
train_pred = scaler.inverse_transform(train_pred)
y_train = scaler.inverse_transform([Y_train])
test_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform([Y_test])
predictions = test_pred

# %%
# To make a dataframe of original and predicted value:
lstm_df=[]
for i in range (0, len(predictions)):
  lstm_df.append((predictions[i][0]))
final_data = pd.DataFrame((y_test[0]))
#final_data = pd.DataFrame((Y_test))
final_data.rename(columns = {0:'original_value'}, inplace = True)
final_data['predicted_value'] = lstm_df

# %%
import math
from sklearn.metrics import mean_squared_error
testset = math.sqrt(mean_squared_error(final_data['original_value'], final_data['predicted_value']))
print("The RMSE prediction value on testset: ",testset)
# Out:
# The RMSE prediction value on testset:  1.4367194408319681

# %%
final_df2= hourly_data.reset_index()
# Comparing the forecasts with the actual values
yhat = [x[0] for x in model2.predict(X_test)]
y = [y for y in Y_test]
# Creating the frame to store both predictions
days = final_df2[['Date_time']].values[-len(y):]
df = pd.DataFrame(days,columns = ['Date_time'])
result = pd.concat([df, final_data], axis=1, join='inner')

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(result.Date_time, result.original_value, color='red', label='original')
plt.plot(result.Date_time, result.predicted_value, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()

# %%
df.to_csv('raw_data.csv', index=False)
df.to_excel('raw_data.xls', index=False)

# %%
from google.colab import files

# e.g. save pandas output as csv
result.to_csv('DMA_225_ULSTM_modified.csv')

# or any other file as usual
# with open('example.csv', 'w') as f:
#   f.write('your strings here')

files.download('DMA_225_ULSTM_modified.csv')
