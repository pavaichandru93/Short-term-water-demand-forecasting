# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571

# %% [markdown]
# Observation :
#
# 1.The ADF statistic value of -2. The more negative this statistic, the more likely we are to reject the null hypothesis (we have a stationary dataset).

# %%
#Kwiatkowski-Phillips-Schmidt-Shin test
#Null Hypothesis (H0): stationary.
#Alternate Hypothesis (H1): non-stationary

KPSS_Check_Stationary = kpss(daily_data)
KPSS_Check_Stationary
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1875: FutureWarning:
#
# The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
# (0.6356467832598806,
#  0.019395746976374494,
#  17,
#  {'1%': 0.739, '10%': 0.347, '2.5%': 0.574, '5%': 0.463})

# %% [markdown]
# Observation : 1.The ADF statistic value of 0.63. The positive value is statistic, and hence we have a stationary dataset

# %%
res=sm.tsa.seasonal_decompose(daily_data,period=12)
fig = res.plot()
fig.set_figheight(10)
fig.set_figwidth(18)
plt.show()

# %% [markdown]
# Baseline model : Persistence model

# %%
# Making a df
Original = daily_data["DMA_225"].to_frame().rename(columns = {"DMA_225": "Original" })
Forecast  = daily_data["DMA_225"].to_frame().shift(1).rename(columns = {"DMA_225": "Forecast" })
baseline = pd.concat([Original,Forecast],axis=1)
final = baseline[1:]#there is no prediction for first row due to shifting.
# Calculate the RMSE
rmse = np.sqrt(mean_squared_error(final.Original, final.Forecast))
rmse = round(rmse, 3)
print (" The root mean square value on dataset: ",rmse)
# Out:
#  The root mean square value on dataset:  94.632

# %%
baseline_model = final[['Forecast']]
baseline_model.plot(grid=True)
plt.figure(figsize=(22,10))

# %%
final.plot(figsize=(12,8))

# %%
baseline_graph = final[-90:]
rmse1 = np.sqrt(mean_squared_error(baseline_graph.Original, baseline_graph.Forecast))
rmse1 = round(rmse1, 3)
print (" The root mean square value on dataset using baseline model: ",rmse1)
baseline_graph.plot(figsize=(12,8))
# Out:
#  The root mean square value on dataset using baseline model:  125.565

# %% [markdown]
# Sarimax with 12 grid search

# %%
train = daily_data[:-90]
test = daily_data[-90:]

# %%
# Getting best arima model 
p = d = q = range(0, 2)
pdq_cal = list(itertools.product(p, d, q))
# generation of different combinations of seasonal p, q and q triplets
pdq_seasonal = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
aic_bestvalue = np.inf
pdq_bestvalue = None
pdq_seasonal_best = None
tempmodel = None
for params in pdq_cal:   
    for seasonal_params in pdq_seasonal: 
        tempmodel = SARIMAX(train['DMA_225'],order=params,seasonal_order = seasonal_params,enforce_invertibility=False,enforce_stationarity=False)
        results = tempmodel.fit(disp=False)
        if results.aic < aic_bestvalue:
            aic_bestvalue = results.aic
            pdq_bestvalue = params
            pdq_seasonal_best = seasonal_params
print("Best ARIMA with seasonality (SARIMAX) {} x {} model - AIC:{}".format(pdq_bestvalue,pdq_seasonal_best,aic_bestvalue))
# Out:
# Best ARIMA with seasonality (SARIMAX) (1, 1, 1) x (0, 1, 1, 12) model - AIC:2915.3853236187956

# %%
train.head(2)
# Out:
#                DMA_225
# Date_time
# 2016-04-01  354.219001
# 2016-04-02  313.328000

# %%
test.head(2)
# Out:
#                DMA_225
# Date_time
# 2017-01-01  318.552999
# 2017-01-02  316.326001

# %%
test.tail(2)
# Out:
#                DMA_225
# Date_time
# 2017-03-30  193.332001
# 2017-03-31  191.109001

# %%
# Training the model on the full dataset and predict last 24 hours output
model =  SARIMAX(train,order = (1, 1, 1), 
                        seasonal_order =(0, 1, 1, 12),enforce_invertibility=False,
                             enforce_stationarity=False)
sarimax = model.fit()
sarimax.plot_diagnostics(figsize=(12, 12))
plt.show()

# %%
final = test.copy()
final['SARIMAX'] = sarimax.predict(start="2017-01-01", end="2017-03-31", dynamic=True)
plt.figure(figsize=(16,8))
plt.plot( train['DMA_225'], label='Train')
plt.plot(test['DMA_225'], label='Test')
plt.plot(final['SARIMAX'], label='SARIMAX')
plt.legend(loc='best')
plt.show()

# %%
testset = test.reset_index()
fd=pd.merge(testset, final.SARIMAX, on="Date_time")
fd
# Out:
#     Date_time      DMA_225     SARIMAX
# 0  2017-01-01   318.552999  374.790260
# 1  2017-01-02   316.326001  381.272277
# 2  2017-01-03  1124.990000  342.934192
# 3  2017-01-04   274.774000  328.037217
# 4  2017-01-05   262.884000  328.045640
# ..        ...          ...         ...
# 85 2017-03-27   212.222000  378.936222
# 86 2017-03-28   177.217999  342.844916
# 87 2017-03-29   177.221000  329.576153
# 88 2017-03-30   193.332001  330.764522
# 89 2017-03-31   191.109001  343.808780
#
# [90 rows x 3 columns]

# %%
# Calculate rmse of original and predicted value
rmse = np.sqrt(mean_squared_error(fd.DMA_225,fd.SARIMAX))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  164.717

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd.Date_time, fd.DMA_225, color='red', label='original')
plt.plot(fd.Date_time, fd.SARIMAX, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()

# %% [markdown]
# # LSTM

# %%
dd = daily_data.values
train_size = int(len(dd)-90)
train_data = dd[:train_size]
test_data = dd[train_size:]

# %%
train_data.shape
# Out:
# (275, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.fit_transform(test_data)

# %%
def matrix_dataset(array_dataset, timesteps=1):
 mat_X, mat_Y = [], []
 for i in range(len(array_dataset)-timesteps-1):
  Z = i+timesteps
  m = array_dataset[i:Z, 0]
  mat_X.append(m)
  n = array_dataset[Z, 0]
  mat_Y.append(n)
 return np.array(mat_X), np.array( mat_Y)


look_back = 27
features = 1
X_train1, Y_train1 = matrix_dataset(train_scaled, look_back)
X_test1, Y_test1 = matrix_dataset(test_scaled, look_back)

# %%
X_train1 = X_train1.reshape((X_train1.shape[0],X_train1.shape[1],1))
X_test1 = X_test1.reshape( (X_test1.shape[0],X_test1.shape[1],1))

# %%
X_train1.shape
# Out:
# (247, 27, 1)

# %%
# Define the LSTM network
model = Sequential()
model.add(LSTM(100,input_shape=(27, 1)))
model.add(Dropout(0.4))
model.add(Dense(60))
# model.add(Dropout(0.3))
model.add(Dense(31))
model.compile(loss='mean_absolute_error', optimizer='adam')
y=model.fit(X_train1,Y_train1, epochs=200, batch_size=2,verbose=1, shuffle=False ,validation_data=(X_test1,Y_test1))
# Out:
# Epoch 1/200
# 124/124 [==============================] - 4s 17ms/step - loss: 0.0453 - val_loss: 0.0197
# Epoch 2/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0483 - val_loss: 0.0206
# Epoch 3/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0473 - val_loss: 0.0196
# Epoch 4/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0465 - val_loss: 0.0215
# Epoch 5/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0452 - val_loss: 0.0206
# Epoch 6/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0437 - val_loss: 0.0202
# Epoch 7/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0423 - val_loss: 0.0189
# Epoch 8/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0417 - val_loss: 0.0181
# Epoch 9/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0412 - val_loss: 0.0191
# Epoch 10/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0391 - val_loss: 0.0176
# Epoch 11/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0414 - val_loss: 0.0185
# Epoch 12/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0404 - val_loss: 0.0191
# Epoch 13/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0382 - val_loss: 0.0179
# Epoch 14/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0380 - val_loss: 0.0187
# Epoch 15/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0368 - val_loss: 0.0176
# Epoch 16/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0378 - val_loss: 0.0175
# Epoch 17/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0386 - val_loss: 0.0186
# Epoch 18/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0369 - val_loss: 0.0190
# Epoch 19/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0365 - val_loss: 0.0186
# Epoch 20/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0385 - val_loss: 0.0183
# Epoch 21/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0360 - val_loss: 0.0169
# Epoch 22/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0371 - val_loss: 0.0192
# Epoch 23/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0368 - val_loss: 0.0176
# Epoch 24/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0346 - val_loss: 0.0170
# Epoch 25/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0370 - val_loss: 0.0182
# Epoch 26/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0359 - val_loss: 0.0167
# Epoch 27/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0346 - val_loss: 0.0167
# Epoch 28/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0359 - val_loss: 0.0188
# Epoch 29/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0339 - val_loss: 0.0176
# Epoch 30/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0362 - val_loss: 0.0177
# Epoch 31/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0337 - val_loss: 0.0169
# Epoch 32/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0356 - val_loss: 0.0169
# Epoch 33/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0329 - val_loss: 0.0168
# Epoch 34/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0338 - val_loss: 0.0171
# Epoch 35/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0340 - val_loss: 0.0169
# Epoch 36/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0345 - val_loss: 0.0186
# Epoch 37/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0322 - val_loss: 0.0182
# Epoch 38/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0333 - val_loss: 0.0178
# Epoch 39/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0335 - val_loss: 0.0173
# Epoch 40/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0320 - val_loss: 0.0178
# Epoch 41/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0332 - val_loss: 0.0176
# Epoch 42/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0331 - val_loss: 0.0190
# Epoch 43/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0322 - val_loss: 0.0179
# Epoch 44/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0328 - val_loss: 0.0174
# Epoch 45/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0326 - val_loss: 0.0174
# Epoch 46/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0343 - val_loss: 0.0191
# Epoch 47/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0339 - val_loss: 0.0173
# Epoch 48/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0321 - val_loss: 0.0172
# Epoch 49/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0327 - val_loss: 0.0171
# Epoch 50/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0339 - val_loss: 0.0173
# Epoch 51/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0336 - val_loss: 0.0172
# Epoch 52/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0310 - val_loss: 0.0170
# Epoch 53/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0322 - val_loss: 0.0190
# Epoch 54/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0318 - val_loss: 0.0178
# Epoch 55/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0310 - val_loss: 0.0175
# Epoch 56/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0300 - val_loss: 0.0176
# Epoch 57/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0314 - val_loss: 0.0182
# Epoch 58/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0315 - val_loss: 0.0186
# Epoch 59/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0310 - val_loss: 0.0174
# Epoch 60/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0305 - val_loss: 0.0198
# Epoch 61/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0307 - val_loss: 0.0181
# Epoch 62/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0313 - val_loss: 0.0184
# Epoch 63/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0309 - val_loss: 0.0176
# Epoch 64/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0186
# Epoch 65/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0296 - val_loss: 0.0194
# Epoch 66/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0314 - val_loss: 0.0181
# Epoch 67/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0303 - val_loss: 0.0189
# Epoch 68/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0200
# Epoch 69/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0179
# Epoch 70/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0177
# Epoch 71/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0319 - val_loss: 0.0192
# Epoch 72/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0288 - val_loss: 0.0178
# Epoch 73/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0290 - val_loss: 0.0189
# Epoch 74/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0191
# Epoch 75/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0298 - val_loss: 0.0194
# Epoch 76/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0309 - val_loss: 0.0185
# Epoch 77/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0323 - val_loss: 0.0182
# Epoch 78/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0177
# Epoch 79/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0309 - val_loss: 0.0189
# Epoch 80/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0333 - val_loss: 0.0185
# Epoch 81/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0327 - val_loss: 0.0181
# Epoch 82/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0301 - val_loss: 0.0180
# Epoch 83/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0180
# Epoch 84/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0192
# Epoch 85/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0303 - val_loss: 0.0181
# Epoch 86/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0310 - val_loss: 0.0176
# Epoch 87/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0301 - val_loss: 0.0187
# Epoch 88/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0298 - val_loss: 0.0190
# Epoch 89/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0185
# Epoch 90/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0309 - val_loss: 0.0182
# Epoch 91/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0296 - val_loss: 0.0191
# Epoch 92/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0316 - val_loss: 0.0182
# Epoch 93/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0306 - val_loss: 0.0178
# Epoch 94/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0308 - val_loss: 0.0181
# Epoch 95/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0184
# Epoch 96/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0184
# Epoch 97/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0181
# Epoch 98/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0181
# Epoch 99/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0294 - val_loss: 0.0176
# Epoch 100/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0289 - val_loss: 0.0182
# Epoch 101/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0290 - val_loss: 0.0180
# Epoch 102/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0304 - val_loss: 0.0175
# Epoch 103/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0299 - val_loss: 0.0177
# Epoch 104/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0311 - val_loss: 0.0190
# Epoch 105/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0299 - val_loss: 0.0175
# Epoch 106/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0280 - val_loss: 0.0179
# Epoch 107/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0326 - val_loss: 0.0173
# Epoch 108/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0291 - val_loss: 0.0177
# Epoch 109/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0184
# Epoch 110/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0306 - val_loss: 0.0173
# Epoch 111/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0288 - val_loss: 0.0177
# Epoch 112/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0295 - val_loss: 0.0178
# Epoch 113/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0282 - val_loss: 0.0176
# Epoch 114/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0290 - val_loss: 0.0174
# Epoch 115/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0282 - val_loss: 0.0177
# Epoch 116/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0305 - val_loss: 0.0182
# Epoch 117/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0296 - val_loss: 0.0175
# Epoch 118/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0298 - val_loss: 0.0180
# Epoch 119/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0266 - val_loss: 0.0181
# Epoch 120/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0314 - val_loss: 0.0184
# Epoch 121/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0309 - val_loss: 0.0208
# Epoch 122/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0305 - val_loss: 0.0180
# Epoch 123/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0309 - val_loss: 0.0178
# Epoch 124/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0287 - val_loss: 0.0179
# Epoch 125/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0273 - val_loss: 0.0184
# Epoch 126/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0286 - val_loss: 0.0174
# Epoch 127/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0285 - val_loss: 0.0190
# Epoch 128/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0298 - val_loss: 0.0181
# Epoch 129/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0274 - val_loss: 0.0187
# Epoch 130/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0311 - val_loss: 0.0198
# Epoch 131/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0279 - val_loss: 0.0182
# Epoch 132/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0289 - val_loss: 0.0181
# Epoch 133/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0291 - val_loss: 0.0186
# Epoch 134/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0296 - val_loss: 0.0185
# Epoch 135/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0304 - val_loss: 0.0200
# Epoch 136/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0278 - val_loss: 0.0174
# Epoch 137/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0280 - val_loss: 0.0191
# Epoch 138/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0301 - val_loss: 0.0194
# Epoch 139/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0295 - val_loss: 0.0179
# Epoch 140/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0270 - val_loss: 0.0181
# Epoch 141/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0298 - val_loss: 0.0174
# Epoch 142/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0302 - val_loss: 0.0176
# Epoch 143/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0277 - val_loss: 0.0184
# Epoch 144/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0284 - val_loss: 0.0188
# Epoch 145/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0283 - val_loss: 0.0180
# Epoch 146/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0295 - val_loss: 0.0185
# Epoch 147/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0271 - val_loss: 0.0189
# Epoch 148/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0332 - val_loss: 0.0188
# Epoch 149/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0315 - val_loss: 0.0208
# Epoch 150/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0313 - val_loss: 0.0190
# Epoch 151/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0289 - val_loss: 0.0194
# Epoch 152/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0288 - val_loss: 0.0199
# Epoch 153/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0289 - val_loss: 0.0181
# Epoch 154/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0264 - val_loss: 0.0177
# Epoch 155/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0184
# Epoch 156/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0194
# Epoch 157/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0275 - val_loss: 0.0181
# Epoch 158/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0275 - val_loss: 0.0184
# Epoch 159/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0269 - val_loss: 0.0188
# Epoch 160/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0272 - val_loss: 0.0217
# Epoch 161/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0352 - val_loss: 0.0193
# Epoch 162/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0286 - val_loss: 0.0199
# Epoch 163/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0293 - val_loss: 0.0220
# Epoch 164/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0284 - val_loss: 0.0179
# Epoch 165/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0282 - val_loss: 0.0195
# Epoch 166/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0266 - val_loss: 0.0171
# Epoch 167/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0272 - val_loss: 0.0183
# Epoch 168/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0289 - val_loss: 0.0201
# Epoch 169/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0269 - val_loss: 0.0171
# Epoch 170/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0271 - val_loss: 0.0186
# Epoch 171/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0272 - val_loss: 0.0169
# Epoch 172/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0289 - val_loss: 0.0205
# Epoch 173/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0265 - val_loss: 0.0180
# Epoch 174/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0268 - val_loss: 0.0173
# Epoch 175/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0333 - val_loss: 0.0203
# Epoch 176/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0284 - val_loss: 0.0195
# Epoch 177/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0271 - val_loss: 0.0198
# Epoch 178/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0314 - val_loss: 0.0194
# Epoch 179/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0272 - val_loss: 0.0166
# Epoch 180/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0273 - val_loss: 0.0200
# Epoch 181/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0285 - val_loss: 0.0215
# Epoch 182/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0308 - val_loss: 0.0198
# Epoch 183/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0269 - val_loss: 0.0190
# Epoch 184/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0267 - val_loss: 0.0214
# Epoch 185/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0280 - val_loss: 0.0178
# Epoch 186/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0287 - val_loss: 0.0163
# Epoch 187/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0271 - val_loss: 0.0237
# Epoch 188/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0274 - val_loss: 0.0179
# Epoch 189/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0256 - val_loss: 0.0199
# Epoch 190/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0276 - val_loss: 0.0194
# Epoch 191/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0271 - val_loss: 0.0182
# Epoch 192/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0262 - val_loss: 0.0217
# Epoch 193/200
# 124/124 [==============================] - 2s 15ms/step - loss: 0.0294 - val_loss: 0.0169
# Epoch 194/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0249 - val_loss: 0.0176
# Epoch 195/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0299 - val_loss: 0.0214
# Epoch 196/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0277 - val_loss: 0.0200
# Epoch 197/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0265 - val_loss: 0.0174
# Epoch 198/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0262 - val_loss: 0.0176
# Epoch 199/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0279 - val_loss: 0.0190
# Epoch 200/200
# 124/124 [==============================] - 2s 14ms/step - loss: 0.0276 - val_loss: 0.0179

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(y.history['loss'])
    plt.plot(y.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(y,'LSTM')

# %%
# Generate predictions
train_pred = model.predict(X_train1)
#evaluation = model.evaluate(x=X_test, y=y_test, verbose=1)
test_pred = model.predict(X_test1)

# %%
# De-standardising the output to original value
train_pred = scaler.inverse_transform(train_pred)
y_train = scaler.inverse_transform([Y_train1])
test_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform([Y_test1])
predictions = test_pred

# %%
# To make a dataframe of original and predicted value:
lstm_df=[]
for i in range (0, len(predictions)):
  lstm_df.append((predictions[i][0]))
final_data = pd.DataFrame((y_test[0]))
#final_data = pd.DataFrame((Y_test))
final_data.rename(columns = {0:'original_value'}, inplace = True)
final_data['predicted_value'] = lstm_df

# %%
import math
from sklearn.metrics import mean_squared_error
testset = math.sqrt(mean_squared_error(final_data['original_value'], final_data['predicted_value']))
print("The RMSE prediction value on testset: ",testset)
# Out:
# The RMSE prediction value on testset:  21.772750214968465

# %%
final_df2= daily_data.reset_index()
# Comparing the forecasts with the actual values
yhat = [x[0] for x in model.predict(X_test1)]
y = [y for y in Y_test1]
# Creating the frame to store both predictions
days = final_df2[['Date_time']].values[-len(y):]
df = pd.DataFrame(days,columns = ['Date_time'])
result = pd.concat([df, final_data], axis=1, join='inner')

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(result.Date_time, result.original_value, color='red', label='original')
plt.plot(result.Date_time, result.predicted_value, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()

# %% [markdown]
# sarimax 24 gour grid search

# %%
# One month prediction:
trainset = daily_data[:-90]
testset = daily_data[-90:]

# %%
# Getting best arima model 
p = d = q = range(0, 2)
pdq_cal = list(itertools.product(p, d, q))
# generation of different combinations of seasonal p, q and q triplets
pdq_seasonal = [(x[0], x[1], x[2], 24) for x in list(itertools.product(p, d, q))]
aic_bestvalue = np.inf
pdq_bestvalue = None
pdq_seasonal_best = None
tempmodel = None
for params in pdq_cal:   
    for seasonal_params in pdq_seasonal: 
        tempmodel = SARIMAX(trainset['DMA_225'],order=params,seasonal_order = seasonal_params,enforce_invertibility=False,enforce_stationarity=False)
        results = tempmodel.fit(disp=False)
        if results.aic < aic_bestvalue:
            aic_bestvalue = results.aic
            pdq_bestvalue = params
            pdq_seasonal_best = seasonal_params
print("Best ARIMA with seasonality (SARIMAX) {} x {} model - AIC:{}".format(pdq_bestvalue,pdq_seasonal_best,aic_bestvalue))
# Out:
# Best ARIMA with seasonality (SARIMAX) (1, 1, 1) x (0, 1, 1, 24) model - AIC:2663.6155246086932

# %%
# Training the model on the full dataset and predict last 24 hours output
model =  SARIMAX(trainset,order = (1, 1, 1), 
                        seasonal_order =(0, 1, 1, 24),enforce_invertibility=False,
                             enforce_stationarity=False)
sarimax_mdl = model.fit()
sarimax_mdl.plot_diagnostics(figsize=(12, 12))
plt.show()

# %%
testset
# Out:
#                 DMA_225
# Date_time
# 2017-01-01   318.552999
# 2017-01-02   316.326001
# 2017-01-03  1124.990000
# 2017-01-04   274.774000
# 2017-01-05   262.884000
# ...                 ...
# 2017-03-27   212.222000
# 2017-03-28   177.217999
# 2017-03-29   177.221000
# 2017-03-30   193.332001
# 2017-03-31   191.109001
#
# [90 rows x 1 columns]

# %%
final_df = testset.copy()
final_df['SARIMAX_pred'] = sarimax_mdl.predict(start="2017-01-01",end='2017-03-31', dynamic=True)
plt.figure(figsize=(16,8))
plt.plot( trainset['DMA_225'], label='Train')
plt.plot(testset['DMA_225'], label='Test')
plt.plot(final_df['SARIMAX_pred'], label='SARIMAX_pred')
plt.legend(loc='best')
plt.show()

# %%
test_df = testset.reset_index()
fd_df=pd.merge(test_df, final_df.SARIMAX_pred, on="Date_time")
fd_df
# Out:
#     Date_time      DMA_225  SARIMAX_pred
# 0  2017-01-01   318.552999    397.577232
# 1  2017-01-02   316.326001    406.836168
# 2  2017-01-03  1124.990000    349.414444
# 3  2017-01-04   274.774000    317.737037
# 4  2017-01-05   262.884000    317.198822
# ..        ...          ...           ...
# 85 2017-03-27   212.222000    330.935490
# 86 2017-03-28   177.217999    317.723173
# 87 2017-03-29   177.221000    323.714264
# 88 2017-03-30   193.332001    328.199820
# 89 2017-03-31   191.109001    338.194134
#
# [90 rows x 3 columns]

# %%
# Calculate rmse of original and predicted value
rmse = np.sqrt(mean_squared_error(fd_df.DMA_225,fd_df.SARIMAX_pred))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  161.183

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd_df.Date_time, fd_df.DMA_225, color='red', label='original')
plt.plot(fd_df.Date_time, fd_df.SARIMAX_pred, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()
