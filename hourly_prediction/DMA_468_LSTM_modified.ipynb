# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib as mpl
from datetime import datetime
import plotly.express as px
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation

np.random.seed(42)
tf.random.set_seed(42)

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls'/content/gdrive/My Drive/Thesis'
# Out:
# dataframe_dma_flow_1D.csv       dataframe_flow_variable_60min.csv
# dataframe_dma_flow_60min.csv    DMA_225.csv
# dataframe_flow_1D.csv           DMA_468.csv
# dataframe_flow_variable_1D.csv  persistence_results.pkl

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/DMA_468.csv")
data['Date-time'] = pd.to_datetime(data['Date-time'], dayfirst=True, errors='coerce')

# %%
data.rename( columns={'Flow':'DMA_468','Date-time':'Date_time'}, inplace=True )

# %%
data_DMA468 = data[['Date_time','DMA_468']]

# %%
data_DMA468_indexed = data_DMA468.set_index('Date_time')

# %%
data_DMA468_indexed.shape
# Out:
# (35040, 1)

# %%
# Making hourly data 
hourly_data = data_DMA468_indexed.resample('h').sum()

hourly_data.isnull().sum().sum()
hourly_data.isna().sum().sum()
data_hourly = hourly_data.values

#Scaling the data 
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_hourly)
scaled_hourlydata = pd.DataFrame(scaled_data)

# Restructuring the data
def reshaped_hourlydata(data,step_input,step_output):
  final_data =  np.array([data[i:i + (step_input+step_output)].copy() for i in range(len(data) - (step_input+step_output))])
  return final_data

final_hourlydata = reshaped_hourlydata(scaled_hourlydata,12,24)
#final_hourlydata = reshaped_hourlydata(data_hourly,12,24)
final_hourlydata.shape
# Out:
# (8724, 36, 1)

# %%
train_size = int(len(final_hourlydata)*0.6)
remaining_data = len(final_hourlydata) - train_size
# # With the remaining data 70% is considered for validation set and 30% for test set.
validation_data = int((remaining_data)*0.7)
testing_data = remaining_data-validation_data
valid_size = (train_size)+(validation_data)
# #valid_size = int(len(final_hourlydata)*0.9)

# train_size = 5234
# valid_size = 7851
# Restructing the dataset:
step_input = 12
step_output = 24

train_X = final_hourlydata[:train_size, :step_input]
valid_X = final_hourlydata[train_size:valid_size, :step_input]
test_X = final_hourlydata[valid_size:, :step_input]
y = np.empty((len(final_hourlydata), step_input, step_output))
for future_value in range(1, step_output + 1):
    y[..., future_value - 1] = final_hourlydata[..., future_value:future_value + step_input, 0]
train_y = y[:train_size]
valid_y = y[train_size:valid_size]
test_y = y[valid_size:]

print("The shape of train_X is:",train_X.shape)
print("The shape of valid_X is:",valid_X.shape)
print("The shape of test_X is:",test_X.shape)

print("The shape of train_y is:",train_y.shape)
print("The shape of valid_y is:",valid_y.shape)
print("The shape of test_y is:",test_y.shape)
# Out:
# The shape of train_X is: (5234, 12, 1)
# The shape of valid_X is: (2443, 12, 1)
# The shape of test_X is: (1047, 12, 1)
# The shape of train_y is: (5234, 12, 24)
# The shape of valid_y is: (2443, 12, 24)
# The shape of test_y is: (1047, 12, 24)

# %% [markdown]
# LSTM

# %%
model8 = keras.models.Sequential([
keras.layers.LSTM(150,return_sequences=True, input_shape=(12,1)),
keras.layers.Dropout(0.1),
keras.layers.Dense(170,kernel_initializer='normal'),
#keras.layers.Dropout(0.35),
keras.layers.Dense(140,kernel_initializer='normal'),
#keras.layers.Dropout(0.45),
keras.layers.Dense(24)
])
opt = keras.optimizers.Adam(learning_rate=0.009)
model8.compile(loss='mse', optimizer=opt),
history8 = model8.fit(train_X,train_y, batch_size = 70,epochs = 350,validation_data=(valid_X, valid_y))
# Out:
# Epoch 1/350
# 75/75 [==============================] - 6s 50ms/step - loss: 0.0134 - val_loss: 0.0050
# Epoch 2/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0059 - val_loss: 0.0043
# Epoch 3/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0055 - val_loss: 0.0041
# Epoch 4/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0050 - val_loss: 0.0036
# Epoch 5/350
# 75/75 [==============================] - 3s 43ms/step - loss: 0.0047 - val_loss: 0.0036
# Epoch 6/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0045 - val_loss: 0.0034
# Epoch 7/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 8/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 9/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 10/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0039 - val_loss: 0.0029
# Epoch 11/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0038 - val_loss: 0.0028
# Epoch 12/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 13/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 14/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0036 - val_loss: 0.0027
# Epoch 15/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 16/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 17/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 18/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 19/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 20/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 21/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 22/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 23/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 24/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 25/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 26/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 27/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 28/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 29/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 30/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 31/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 32/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 33/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 34/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 35/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 36/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 37/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 38/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 39/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 40/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 41/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 42/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 43/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 44/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 45/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 46/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 47/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 48/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 49/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 50/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 51/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 52/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 53/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 54/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 55/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 56/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 57/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 58/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 59/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 60/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 61/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 62/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 63/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 64/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 65/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 66/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 67/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 68/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 69/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 70/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 71/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 72/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 73/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 74/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 75/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 76/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 77/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 78/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 79/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 80/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 81/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 82/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 83/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 84/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 85/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 86/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 87/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 88/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 89/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 90/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 91/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 92/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 93/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 94/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 95/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 96/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 97/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 98/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 99/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 100/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 101/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 102/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 103/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 104/350
# 75/75 [==============================] - 3s 43ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 105/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 106/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 107/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 108/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 109/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 110/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 111/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 112/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 113/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 114/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 115/350
# 75/75 [==============================] - 3s 43ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 116/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 117/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 118/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 119/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 120/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 121/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 122/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 123/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 124/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 125/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 126/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 127/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 128/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 129/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 130/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 131/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 132/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 133/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 134/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 135/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 136/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 137/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 138/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 139/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 140/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 141/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 142/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 143/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 144/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 145/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 146/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 147/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 148/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 149/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 150/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 151/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 152/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 153/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 154/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 155/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 156/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 157/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 158/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 159/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 160/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 161/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 162/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 163/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 164/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 165/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 166/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 167/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 168/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 169/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 170/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 171/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 172/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 173/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 174/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 175/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 176/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 177/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 178/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 179/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 180/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 181/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 182/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 183/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 184/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 185/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 186/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 187/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 188/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 189/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 190/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 191/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 192/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 193/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 194/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 195/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 196/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 197/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 198/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 199/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 200/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 201/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 202/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 203/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 204/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 205/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 206/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 207/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 208/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 209/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 210/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 211/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 212/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 213/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 214/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 215/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 216/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 217/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 218/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 219/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 220/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 221/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 222/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 223/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 224/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 225/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 226/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 227/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 228/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 229/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 230/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 231/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 232/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 233/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 234/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 235/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 236/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 237/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 238/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 239/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 240/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 241/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 242/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 243/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 244/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 245/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 246/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 247/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 248/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 249/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 250/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 251/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 252/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 253/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 254/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 255/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 256/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 257/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 258/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 259/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 260/350
# 75/75 [==============================] - 3s 47ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 261/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 262/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 263/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 264/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 265/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 266/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 267/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 268/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 269/350
# 75/75 [==============================] - 4s 49ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 270/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 271/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 272/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 273/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 274/350
# 75/75 [==============================] - 3s 47ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 275/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 276/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 277/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 278/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 279/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 280/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 281/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 282/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 283/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 284/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 285/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 286/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 287/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 288/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 289/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.7437 - val_loss: 0.0306
# Epoch 290/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0130 - val_loss: 0.0056
# Epoch 291/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0071 - val_loss: 0.0053
# Epoch 292/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0067 - val_loss: 0.0051
# Epoch 293/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 294/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 295/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0061 - val_loss: 0.0046
# Epoch 296/350
# 75/75 [==============================] - 4s 48ms/step - loss: 0.0060 - val_loss: 0.0045
# Epoch 297/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0059 - val_loss: 0.0044
# Epoch 298/350
# 75/75 [==============================] - 3s 47ms/step - loss: 0.0057 - val_loss: 0.0043
# Epoch 299/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 300/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0056 - val_loss: 0.0041
# Epoch 301/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0055 - val_loss: 0.0041
# Epoch 302/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0054 - val_loss: 0.0040
# Epoch 303/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0053 - val_loss: 0.0039
# Epoch 304/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0052 - val_loss: 0.0039
# Epoch 305/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 306/350
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 307/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 308/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 309/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0047 - val_loss: 0.0035
# Epoch 310/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0046 - val_loss: 0.0034
# Epoch 311/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0045 - val_loss: 0.0033
# Epoch 312/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0045 - val_loss: 0.0032
# Epoch 313/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 314/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 315/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 316/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 317/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 318/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 319/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 320/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 321/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 322/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 323/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 324/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 325/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 326/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 327/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 328/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 329/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 330/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 331/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 332/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 333/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 334/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 335/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 336/350
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 337/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 338/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 339/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 340/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 341/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 342/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 343/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 344/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 345/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 346/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 347/350
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 348/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 349/350
# 75/75 [==============================] - 3s 46ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 350/350
# 75/75 [==============================] - 3s 47ms/step - loss: 0.0032 - val_loss: 0.0023

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(history8,'LSTm')

# %%
#Generate predictions
train_pred = model8.predict(train_X)
#evaluation = model.evaluate(x=X_test, y=y_test, verbose=1)
test_pred = model8.predict(test_X)
predictions = test_pred

# %%
# To make a dataframe of original and predicted value:
lstm_df=[]
for i in range (0, len(predictions)):
  lstm_df.append((predictions[i][0][step_output-1]))
final_df = pd.DataFrame((test_y[:,0]))
final_df.rename(columns = {0:'original_value'}, inplace = True)
final_df['predicted_value'] = lstm_df

# %%
# To calculate the percentage difference between actual and predicted value:
final_df['total_difference'] = (final_df['predicted_value'] - final_df['original_value']).abs()
final_df['percentage_difference'] = ((final_df['total_difference'])/(final_df['original_value']))*100

# %%
import math
from sklearn.metrics import mean_squared_error
testset = math.sqrt(mean_squared_error(final_df['original_value'], final_df['predicted_value']))
print("The RMSE prediction value on testset: ",testset)
# Out:
# The RMSE prediction value on testset:  0.05656395778193337

# %%
# To make complete df:
y = [y[0] for y in test_y]
df_r = hourly_data.reset_index()
days = df_r['Date_time'].values[-len(y):]
df = pd.DataFrame(days,columns = ['Date_time'])
result = pd.concat([df, final_df], axis=1, join='inner')
result.shape
# Out:
# (1047, 28)

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(result.Date_time, result.original_value, color='red', label='original')
plt.plot(result.Date_time, result.predicted_value, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()

# %%
from google.colab import files

# e.g. save pandas output as csv
result.to_csv('DMA_468_ULSTM_modifed.csv')

# or any other file as usual
# with open('example.csv', 'w') as f:
#   f.write('your strings here')

files.download('DMA_468_ULSTM_modifed.csv')
