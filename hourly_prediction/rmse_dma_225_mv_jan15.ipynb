# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib as mpl
from datetime import datetime
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, LeakyReLU,ReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation


mpl.rcParams['figure.figsize'] = (20, 15)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf 
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/dataframe_flow_variable_60min.csv")
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'])
data.rename( columns={'Unnamed: 0':'Date_time','225':'DMA_225'}, inplace=True )
data_DMA225 = data[['Date_time','DMA_225','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']]
data_DMA225_indexed = data_DMA225.set_index('Date_time')
data_DMA225_indexed[['DMA_225','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7efd7011d350>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd7007d710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd700b6a50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd70070d50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd700340d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd6ffea410>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd6ffa1750>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd6ff5aa90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7efd6ff0ee10>],
#       dtype=object)

# %%
# Making hourly data 
hourly_data = data_DMA225_indexed.resample('h').sum()
#hr = hourly_data.values
#Train and test split
split = 240
train = hourly_data[:-500]
test = hourly_data[-500:]

# %%
#Separate dates for future plotting
trainset = train.reset_index()
train_dates = pd.to_datetime(trainset['Date_time'])
len(train_dates)
# Out:
# 1708

# %%
#Variables for training
cols = list(train)[:10]
df_for_training = train[cols]

#LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
# normalize the dataset
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
df_for_training_scaled.shape
# Out:
# (1708, 9)

# %%
#Empty lists to be populated using formatted training data
trainX = []
trainY = []

n_future = 1   # Number of days we want to look into the future based on the past days.
n_past = 24  # Number of past days we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)
#In my example, my df_for_training_scaled has a shape (12823, 5)
#12823 refers to the number of data points and 5 refers to the columns (multi-variables).
for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))

trainX, trainY = np.array(trainX), np.array(trainY)
# Out:
# trainX shape == (1684, 24, 9).
# trainY shape == (1684, 1).

# %%
import tensorflow
model = Sequential()
model.add(LSTM(50, activation='relu',input_shape=(trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LeakyReLU(alpha=0.9)) 
model.add(Dropout(0.17))
#model.add(Dense(20))
model.add(Dense(30))
#model.add(LeakyReLU(alpha=0.9))
model.add(LSTM(30,return_sequences=False))
model.add(LeakyReLU(alpha=0.9))
model.add(Dropout(0.2))
#10000005
model.add(Dense(trainY.shape[1]))
initial_learning_rate = 0.5
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000035,
    decay_rate=1.08,
    staircase=True)
opt = tf.keras.optimizers.Adam(lr_schedule, epsilon=1.25, beta_1=0.19,beta_2=0.53)
model.compile(optimizer=opt, loss='mae')
model.summary()


# fit the model
history = model.fit(trainX, trainY, epochs=50, batch_size=1000, validation_split=0.2, verbose=1)
# Out:
# Model: "sequential_55"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_110 (LSTM)             (None, 24, 50)            12000
#
#  leaky_re_lu_165 (LeakyReLU)  (None, 24, 50)           0
#
#  dropout_110 (Dropout)       (None, 24, 50)            0
#
#  dense_127 (Dense)           (None, 24, 30)            1530
#
#  lstm_111 (LSTM)             (None, 30)                7320
#
#  leaky_re_lu_166 (LeakyReLU)  (None, 30)               0
#
#  dropout_111 (Dropout)       (None, 30)                0
#
#  dense_128 (Dense)           (None, 1)                 31
#
# =================================================================
# Total params: 20,881
# Trainable params: 20,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2/2 [==============================] - 5s 885ms/step - loss: 0.8948 - val_loss: 0.8138
# Epoch 2/50
# 2/2 [==============================] - 0s 144ms/step - loss: 0.8653 - val_loss: 0.7999
# Epoch 3/50
# 2/2 [==============================] - 0s 141ms/step - loss: 0.8450 - val_loss: 0.7750
# Epoch 4/50
# 2/2 [==============================] - 0s 156ms/step - loss: 0.8284 - val_loss: 0.7505
# Epoch 5/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.7996 - val_loss: 0.6956
# Epoch 6/50
# 2/2 [==============================] - 0s 141ms/step - loss: 0.7496 - val_loss: 0.7400
# Epoch 7/50
# 2/2 [==============================] - 0s 143ms/step - loss: 0.6821 - val_loss: 0.6607
# Epoch 8/50
# 2/2 [==============================] - 0s 176ms/step - loss: 0.6515 - val_loss: 0.8933
# Epoch 9/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.7197 - val_loss: 0.5424
# Epoch 10/50
# 2/2 [==============================] - 0s 150ms/step - loss: 0.5637 - val_loss: 0.4344
# Epoch 11/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.4879 - val_loss: 0.4250
# Epoch 12/50
# 2/2 [==============================] - 0s 160ms/step - loss: 0.4539 - val_loss: 0.4262
# Epoch 13/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.4436 - val_loss: 0.4353
# Epoch 14/50
# 2/2 [==============================] - 0s 148ms/step - loss: 0.4387 - val_loss: 0.3860
# Epoch 15/50
# 2/2 [==============================] - 0s 148ms/step - loss: 0.4180 - val_loss: 0.4013
# Epoch 16/50
# 2/2 [==============================] - 0s 153ms/step - loss: 0.4159 - val_loss: 0.5249
# Epoch 17/50
# 2/2 [==============================] - 0s 147ms/step - loss: 0.4682 - val_loss: 0.4317
# Epoch 18/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.3999 - val_loss: 0.3985
# Epoch 19/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.3960 - val_loss: 0.5028
# Epoch 20/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.4302 - val_loss: 0.4894
# Epoch 21/50
# 2/2 [==============================] - 0s 147ms/step - loss: 0.4135 - val_loss: 0.3673
# Epoch 22/50
# 2/2 [==============================] - 0s 148ms/step - loss: 0.3780 - val_loss: 0.3787
# Epoch 23/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.3741 - val_loss: 0.4000
# Epoch 24/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.4218 - val_loss: 0.4218
# Epoch 25/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.4080 - val_loss: 0.3401
# Epoch 26/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.3632 - val_loss: 0.3500
# Epoch 27/50
# 2/2 [==============================] - 0s 161ms/step - loss: 0.3639 - val_loss: 0.4057
# Epoch 28/50
# 2/2 [==============================] - 0s 151ms/step - loss: 0.3846 - val_loss: 0.4811
# Epoch 29/50
# 2/2 [==============================] - 0s 147ms/step - loss: 0.4160 - val_loss: 0.4026
# Epoch 30/50
# 2/2 [==============================] - 0s 165ms/step - loss: 0.3726 - val_loss: 0.4057
# Epoch 31/50
# 2/2 [==============================] - 0s 152ms/step - loss: 0.3697 - val_loss: 0.4163
# Epoch 32/50
# 2/2 [==============================] - 0s 148ms/step - loss: 0.3633 - val_loss: 0.3342
# Epoch 33/50
# 2/2 [==============================] - 0s 158ms/step - loss: 0.3468 - val_loss: 0.4335
# Epoch 34/50
# 2/2 [==============================] - 0s 147ms/step - loss: 0.3829 - val_loss: 0.4361
# Epoch 35/50
# 2/2 [==============================] - 0s 155ms/step - loss: 0.3755 - val_loss: 0.4005
# Epoch 36/50
# 2/2 [==============================] - 0s 158ms/step - loss: 0.3576 - val_loss: 0.3744
# Epoch 37/50
# 2/2 [==============================] - 0s 154ms/step - loss: 0.3435 - val_loss: 0.3759
# Epoch 38/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.3530 - val_loss: 0.3257
# Epoch 39/50
# 2/2 [==============================] - 0s 159ms/step - loss: 0.3334 - val_loss: 0.3385
# Epoch 40/50
# 2/2 [==============================] - 0s 148ms/step - loss: 0.3483 - val_loss: 0.3649
# Epoch 41/50
# 2/2 [==============================] - 0s 161ms/step - loss: 0.3602 - val_loss: 0.3255
# Epoch 42/50
# 2/2 [==============================] - 0s 145ms/step - loss: 0.3287 - val_loss: 0.3293
# Epoch 43/50
# 2/2 [==============================] - 0s 146ms/step - loss: 0.3307 - val_loss: 0.3207
# Epoch 44/50
# 2/2 [==============================] - 0s 153ms/step - loss: 0.3255 - val_loss: 0.3046
# Epoch 45/50
# 2/2 [==============================] - 0s 146ms/step - loss: 0.3336 - val_loss: 0.2897
# Epoch 46/50
# 2/2 [==============================] - 0s 153ms/step - loss: 0.3519 - val_loss: 0.2988
# Epoch 47/50
# 2/2 [==============================] - 0s 150ms/step - loss: 0.3471 - val_loss: 0.2886
# Epoch 48/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.3340 - val_loss: 0.2958
# Epoch 49/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.3091 - val_loss: 0.3708
# Epoch 50/50
# 2/2 [==============================] - 0s 149ms/step - loss: 0.3483 - val_loss: 0.4744

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(history,'LSTM')

# %%
n_past = 24
n_days_for_prediction=524  #let us predict past 15 days

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq='1H').tolist()

#Make prediction
prediction = model.predict(trainX[-n_days_for_prediction:])
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
# Convert timestamp to date
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i)
    
df_forecast = pd.DataFrame({'Date_time':np.array(forecast_dates), 'DMA_225_pred':y_pred_future})
df_forecast['Date_time']=pd.to_datetime(df_forecast['Date_time'])

# making predicted df

df1=df_forecast[24:]
df1= df1.reset_index()
df1= df1.drop(['index'], axis=1)

# test dataset

t1 = test.reset_index()
t1 = t1[['Date_time','DMA_225']]

# final df
fd=pd.merge(t1, df1, on="Date_time")

# %%
#Calculate rmse
# Root Mean Square Error (RMSE)
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math
rmse = np.sqrt(mean_squared_error(fd.DMA_225,fd.DMA_225_pred))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  1.481

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd.Date_time, fd.DMA_225, color='red', label='original')
plt.plot(fd.Date_time, fd.DMA_225_pred, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()
