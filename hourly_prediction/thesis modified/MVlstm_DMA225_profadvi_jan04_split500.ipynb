# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib as mpl
from datetime import datetime
import plotly.express as px
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM, LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Activation


mpl.rcParams['figure.figsize'] = (20, 15)
mpl.rcParams['axes.grid'] = False

import tensorflow as tf 
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/dataframe_flow_variable_60min.csv")
data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'])
data.rename( columns={'Unnamed: 0':'Date_time','225':'DMA_225'}, inplace=True )
data_DMA225 = data[['Date_time','DMA_225','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']]
data_DMA225_indexed = data_DMA225.set_index('Date_time')
data_DMA225_indexed[['DMA_225','tempC','HeatIndexC','FeelsLikeC','WindChillC','windspeedKmph','sunHour','precipMM','humidity']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa3cf0b8d10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3cf041390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3cf0b88d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3cf06f950>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3cef6ab10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3cef23e90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3ceeeb3d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3ceea5710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa3ceea5750>],
#       dtype=object)

# %%
# Making hourly data 
hourly_data = data_DMA225_indexed.resample('h').sum()

#Train and test split
#split = 240
train = hourly_data[:-500]
test = hourly_data[-500:]

# %%
#Separate dates for future plotting
trainset = train.reset_index()
train_dates = pd.to_datetime(trainset['Date_time'])
len(train_dates)
# Out:
# 1708

# %%
#Variables for training
cols = list(train)[:10]
df_for_training = train[cols]

#LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
# normalize the dataset
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)
df_for_training_scaled.shape
# Out:
# (1708, 9)

# %%
#Empty lists to be populated using formatted training data
trainX = []
trainY = []

n_future = 1   # Number of days we want to look into the future based on the past days.
n_past = 24  # Number of past days we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)
#In my example, my df_for_training_scaled has a shape (12823, 5)
#12823 refers to the number of data points and 5 refers to the columns (multi-variables).
for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))

trainX, trainY = np.array(trainX), np.array(trainY)
# Out:
# trainX shape == (1684, 24, 9).
# trainY shape == (1684, 1).

# %%
import tensorflow
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LeakyReLU(alpha=0.9)) 
model.add(Dropout(0.15))
model.add(LSTM(64,activation='relu',return_sequences=True))
model.add(LeakyReLU(alpha=0.9))
model.add(LSTM(32,activation='relu',return_sequences=False))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))

model.add(Dense(trainY.shape[1]))

#opt = keras.optimizers.Adam(lr = 0.009)
model.compile(optimizer='adam', loss='mae')
model.summary()


# fit the model
history = model.fit(trainX, trainY, epochs=50, batch_size=2000, validation_split=0.2, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 64)            18944
#
#  leaky_re_lu (LeakyReLU)     (None, 24, 64)            0
#
#  dropout (Dropout)           (None, 24, 64)            0
#
#  lstm_1 (LSTM)               (None, 24, 64)            33024
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 24, 64)            0
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32)                0
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 64,417
# Trainable params: 64,417
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1/1 [==============================] - 11s 11s/step - loss: 0.8916 - val_loss: 0.8286
# Epoch 2/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8863 - val_loss: 0.8261
# Epoch 3/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8814 - val_loss: 0.8239
# Epoch 4/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8781 - val_loss: 0.8212
# Epoch 5/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8736 - val_loss: 0.8179
# Epoch 6/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8668 - val_loss: 0.8136
# Epoch 7/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8597 - val_loss: 0.8082
# Epoch 8/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8541 - val_loss: 0.8019
# Epoch 9/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8464 - val_loss: 0.7943
# Epoch 10/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8402 - val_loss: 0.7851
# Epoch 11/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8308 - val_loss: 0.7747
# Epoch 12/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.8140 - val_loss: 0.7613
# Epoch 13/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.8023 - val_loss: 0.7439
# Epoch 14/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7869 - val_loss: 0.7224
# Epoch 15/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.7721 - val_loss: 0.6984
# Epoch 16/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7712 - val_loss: 0.6783
# Epoch 17/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7476 - val_loss: 0.6621
# Epoch 18/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7307 - val_loss: 0.6456
# Epoch 19/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.7116 - val_loss: 0.6289
# Epoch 20/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.6966 - val_loss: 0.6107
# Epoch 21/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6810 - val_loss: 0.5893
# Epoch 22/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6636 - val_loss: 0.5743
# Epoch 23/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.6538 - val_loss: 0.5790
# Epoch 24/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.6339 - val_loss: 0.5746
# Epoch 25/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5998 - val_loss: 0.5594
# Epoch 26/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5783 - val_loss: 0.5323
# Epoch 27/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5617 - val_loss: 0.5036
# Epoch 28/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5575 - val_loss: 0.5136
# Epoch 29/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.5490 - val_loss: 0.5010
# Epoch 30/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5533 - val_loss: 0.5175
# Epoch 31/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.5229 - val_loss: 0.5012
# Epoch 32/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.5086 - val_loss: 0.4761
# Epoch 33/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4934 - val_loss: 0.4700
# Epoch 34/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4830 - val_loss: 0.4671
# Epoch 35/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4734 - val_loss: 0.4626
# Epoch 36/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.4568 - val_loss: 0.4490
# Epoch 37/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4507 - val_loss: 0.4353
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4453 - val_loss: 0.4330
# Epoch 39/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4347 - val_loss: 0.4428
# Epoch 40/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4276 - val_loss: 0.4398
# Epoch 41/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.4268 - val_loss: 0.4477
# Epoch 42/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.4058 - val_loss: 0.4576
# Epoch 43/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.4106 - val_loss: 0.4445
# Epoch 44/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.3954 - val_loss: 0.4272
# Epoch 45/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.3955 - val_loss: 0.4465
# Epoch 46/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.3915 - val_loss: 0.4443
# Epoch 47/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.3773 - val_loss: 0.4192
# Epoch 48/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.3790 - val_loss: 0.3972
# Epoch 49/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.3742 - val_loss: 0.3832
# Epoch 50/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.3568 - val_loss: 0.3929

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(history,'LSTM')

# %%
n_past = 24
n_days_for_prediction=264  #let us predict past 15 days

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq='1H').tolist()

#Make prediction
prediction = model.predict(trainX[-n_days_for_prediction:])
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]

# %%
# Convert timestamp to date
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i)
    
df_forecast = pd.DataFrame({'Date_time':np.array(forecast_dates), 'DMA_225_pred':y_pred_future})
df_forecast['Date_time']=pd.to_datetime(df_forecast['Date_time'])

# making predicted df

df1=df_forecast[24:]
df1= df1.reset_index()
df1= df1.drop(['index'], axis=1)

# test dataset

t1 = test.reset_index()
t1 = t1[['Date_time','DMA_225']]

# final df
fd=pd.merge(t1, df1, on="Date_time")

# %%
#Calculate rmse
# Root Mean Square Error (RMSE)
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math
rmse = np.sqrt(mean_squared_error(fd.DMA_225,fd.DMA_225_pred))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  0.835

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd.Date_time, fd.DMA_225, color='red', label='original')
plt.plot(fd.Date_time, fd.DMA_225_pred, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()
