# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 7.4 MB/s
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 34.1 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.0.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.4 statsmodels-0.13.1

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import numpy as np
from datetime import datetime
import plotly.express as px
import itertools
from pylab import rcParams
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False

from math import sqrt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import kpss
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels.api as sm

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
import math
from sklearn.metrics import mean_squared_error

np.random.seed(42)
tf.random.set_seed(42)

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls'/content/gdrive/My Drive/Thesis'
# Out:
# dataframe_dma_flow_1D.csv       dataframe_flow_variable_60min.csv
# dataframe_dma_flow_60min.csv    DMA_225.csv
# dataframe_flow_1D.csv           DMA_468.csv
# dataframe_flow_variable_1D.csv  persistence_results.pkl

# %%
data = pd.read_csv("/content/gdrive/My Drive/Thesis/DMA_225.csv")
data['Date-time'] = pd.to_datetime(data['Date-time'], dayfirst=True, errors='coerce')
data.rename( columns={'Flow':'DMA_225','Date-time':'Date_time'}, inplace=True )
data_DMA225 = data[['Date_time','DMA_225']]

# %%
figure = px.line(data_DMA225,x="Date_time",y="DMA_225",title="DMA_225 with slider")
figure.update_xaxes(rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="12m",
                     step="month",
                     stepmode="backward"),
                dict(count=2,
                     label="8m",
                     step="month",
                     stepmode="backward"),
                dict(count=3,
                     label="4m",
                     step="month",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        )
    )
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3f3d6195-6cad-4dbc-9d23-b38631f22874" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f3d6195-6cad-4dbc-9d23-b38631f22874")) {
#                     Plotly.newPlot(
#                         '3f3d6195-6cad-4dbc-9d23-b38631f22874',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Date_time=%{x}<br>DMA_225=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2016-04-01T00:00:00", "2016-04-01T00:15:00", "2016-04-01T00:30:00", "2016-04-01T00:45:00", "2016-04-01T01:00:00", "2016-04-01T01:15:00", "2016-04-01T01:30:00", "2016-04-01T01:45:00", "2016-04-01T02:00:00", "2016-04-01T02:15:00", "2016-04-01T02:30:00", "2016-04-01T02:45:00", "2016-04-01T03:00:00", "2016-04-01T03:15:00", "2016-04-01T03:30:00", "2016-04-01T03:45:00", "2016-04-01T04:00:00", "2016-04-01T04:15:00", "2016-04-01T04:30:00", "2016-04-01T04:45:00", "2016-04-01T05:00:00", "2016-04-01T05:15:00", "2016-04-01T05:30:00", "2016-04-01T05:45:00", "2016-04-01T06:00:00", "2016-04-01T06:15:00", "2016-04-01T06:30:00", "2016-04-01T06:45:00", "2016-04-01T07:00:00", "2016-04-01T07:15:00", "2016-04-01T07:30:00", "2016-04-01T07:45:00", "2016-04-01T08:00:00", "2016-04-01T08:15:00", "2016-04-01T08:30:00", "2016-04-01T08:45:00", "2016-04-01T09:00:00", "2016-04-01T09:15:00", "2016-04-01T09:30:00", "2016-04-01T09:45:00", "2016-04-01T10:00:00", "2016-04-01T10:15:00", "2016-04-01T10:30:00", "2016-04-01T10:45:00", "2016-04-01T11:00:00", "2016-04-01T11:15:00", "2016-04-01T11:30:00", "2016-04-01T11:45:00", "2016-04-01T12:00:00", "2016-04-01T12:15:00", "2016-04-01T12:30:00", "2016-04-01T12:45:00", "2016-04-01T13:00:00", "2016-04-01T13:15:00", "2016-04-01T13:30:00", "2016-04-01T13:45:00", "2016-04-01T14:00:00", "2016-04-01T14:15:00", "2016-04-01T14:30:00", "2016-04-01T14:45:00", "2016-04-01T15:00:00", "2016-04-01T15:15:00", "2016-04-01T15:30:00", "2016-04-01T15:45:00", "2016-04-01T16:00:00", "2016-04-01T16:15:00", "2016-04-01T16:30:00", "2016-04-01T16:45:00", "2016-04-01T17:00:00", "2016-04-01T17:15:00", "2016-04-01T17:30:00", "2016-04-01T17:45:00", "2016-04-01T18:00:00", "2016-04-01T18:15:00", "2016-04-01T18:30:00", "2016-04-01T18:45:00", "2016-04-01T19:00:00", "2016-04-01T19:15:00", "2016-04-01T19:30:00", "2016-04-01T19:45:00", "2016-04-01T20:00:00", "2016-04-01T20:15:00", "2016-04-01T20:30:00", "2016-04-01T20:45:00", "2016-04-01T21:00:00", "2016-04-01T21:15:00", "2016-04-01T21:30:00", "2016-04-01T21:45:00", "2016-04-01T22:00:00", "2016-04-01T22:15:00", "2016-04-01T22:30:00", "2016-04-01T22:45:00", "2016-04-01T23:00:00", "2016-04-01T23:15:00", "2016-04-01T23:30:00", "2016-04-01T23:45:00", "2016-04-02T00:00:00", "2016-04-02T00:15:00", "2016-04-02T00:30:00", "2016-04-02T00:45:00", "2016-04-02T01:00:00", "2016-04-02T01:15:00", "2016-04-02T01:30:00", "2016-04-02T01:45:00", "2016-04-02T02:00:00", "2016-04-02T02:15:00", "2016-04-02T02:30:00", "2016-04-02T02:45:00", "2016-04-02T03:00:00", "2016-04-02T03:15:00", "2016-04-02T03:30:00", "2016-04-02T03:45:00", "2016-04-02T04:00:00", "2016-04-02T04:15:00", "2016-04-02T04:30:00", "2016-04-02T04:45:00", "2016-04-02T05:00:00", "2016-04-02T05:15:00", "2016-04-02T05:30:00", "2016-04-02T05:45:00", "2016-04-02T06:00:00", "2016-04-02T06:15:00", "2016-04-02T06:30:00", "2016-04-02T06:45:00", "2016-04-02T07:00:00", "2016-04-02T07:15:00", "2016-04-02T07:30:00", "2016-04-02T07:45:00", "2016-04-02T08:00:00", "2016-04-02T08:15:00", "2016-04-02T08:30:00", "2016-04-02T08:45:00", "2016-04-02T09:00:00", "2016-04-02T09:15:00", "2016-04-02T09:30:00", "2016-04-02T09:45:00", "2016-04-02T10:00:00", "2016-04-02T10:15:00", "2016-04-02T10:30:00", "2016-04-02T10:45:00", "2016-04-02T11:00:00", "2016-04-02T11:15:00", "2016-04-02T11:30:00", "2016-04-02T11:45:00", "2016-04-02T12:00:00", "2016-04-02T12:15:00", "2016-04-02T12:30:00", "2016-04-02T12:45:00", "2016-04-02T13:00:00", "2016-04-02T13:15:00", "2016-04-02T13:30:00", "2016-04-02T13:45:00", "2016-04-02T14:00:00", "2016-04-02T14:15:00", "2016-04-02T14:30:00", "2016-04-02T14:45:00", "2016-04-02T15:00:00", "2016-04-02T15:15:00", "2016-04-02T15:30:00", "2016-04-02T15:45:00", "2016-04-02T16:00:00", "2016-04-02T16:15:00", "2016-04-02T16:30:00" ...

# %%
data_DMA225_indexed = data_DMA225.set_index('Date_time')
daily_data = data_DMA225_indexed.resample('D').sum()

# %% [markdown]
# # Stationarity check

# %%
#Statistical information
daily_data.describe()
# Out:
#            DMA_225
# count   365.000000
# mean    350.539808
# std     146.132718
# min     160.559001
# 25%     295.883001
# 50%     330.224000
# 75%     390.109999
# max    1448.776001

# %%
# Looking at plots
DMA225_df_indexed = daily_data[['DMA_225']]
DMA225_df_indexed.plot(grid=True)
plt.figure(figsize=(22,10))

# %%
# Augmented Dickey-Fuller test
#Null Hypothesis (H0): If failed to be rejected, meaning it is non-stationary. It has some time dependent structure.
#Alternate Hypothesis (H1): The null hypothesis is rejected;  meaning it is stationary. It does not have time-dependent structure.

ADF_Check_Stationary = adfuller(daily_data)
print('ADF Statistic: %f' % ADF_Check_Stationary[0])
print('p-value: %f' % ADF_Check_Stationary[1])
print('Critical Values:')
for key, value in ADF_Check_Stationary[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -2.812360
# p-value: 0.056530
# Critical Values:
# 	1%: -3.449
# 	5%: -2.870
# 	10%: -2.571

# %% [markdown]
# Observation :
#
# 1.The ADF statistic value of -2.81. The more negative this statistic, the more likely we are to reject the null hypothesis (we have a stationary dataset).

# %%
#Kwiatkowski-Phillips-Schmidt-Shin test
#Null Hypothesis (H0): stationary.
#Alternate Hypothesis (H1): non-stationary

KPSS_Check_Stationary = kpss(daily_data)
KPSS_Check_Stationary
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:2012: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
# (0.9260209431084937,
#  0.01,
#  10,
#  {'1%': 0.739, '10%': 0.347, '2.5%': 0.574, '5%': 0.463})

# %% [markdown]
# Observation : 1.The ADF statistic value of 0.63. The positive value is statistic, and hence we have a stationary dataset

# %%
res=sm.tsa.seasonal_decompose(daily_data,period=7)
fig = res.plot()
fig.set_figheight(10)
fig.set_figwidth(18)
plt.show()

# %% [markdown]
# #Baseline model : Persistence model

# %%
# Making a df
Original = daily_data["DMA_225"].to_frame().rename(columns = {"DMA_225": "Original" })
Forecast  = daily_data["DMA_225"].to_frame().shift(1).rename(columns = {"DMA_225": "Forecast" })
baseline = pd.concat([Original,Forecast],axis=1)
final = baseline[1:]#there is no prediction for first row due to shifting.
# Calculate the RMSE
rmse = np.sqrt(mean_squared_error(final.Original, final.Forecast))
rmse = round(rmse, 3)
print (" The root mean square value on dataset: ",rmse)
# Out:
#  The root mean square value on dataset:  94.632

# %%
baseline_model = final[['Forecast']]
baseline_model.plot(grid=True)
plt.figure(figsize=(22,10))

# %%
final.plot(figsize=(12,8))

# %%
baseline_graph = final[-110:]
rmse1 = np.sqrt(mean_squared_error(baseline_graph.Original, baseline_graph.Forecast))
rmse1 = round(rmse1, 3)
print (" The root mean square value on dataset using baseline model: ",rmse1)
baseline_graph.plot(figsize=(12,8))
# Out:
#  The root mean square value on dataset using baseline model:  113.697

# %% [markdown]
# # Sarimax

# %%
train_size = int(len(daily_data)*0.7)
train = daily_data[:train_size]
test = daily_data[train_size:]

# %%
# Getting best arima model 
p = d = q = range(0, 2)
pdq_cal = list(itertools.product(p, d, q))
# generation of different combinations of seasonal p, q and q triplets
pdq_seasonal = [(x[0], x[1], x[2], 7) for x in list(itertools.product(p, d, q))]
aic_bestvalue = np.inf
pdq_bestvalue = None
pdq_seasonal_best = None
tempmodel = None
for params in pdq_cal:   
    for seasonal_params in pdq_seasonal: 
        tempmodel = SARIMAX(train['DMA_225'],order=params,seasonal_order = seasonal_params,enforce_invertibility=False,enforce_stationarity=False)
        results = tempmodel.fit(disp=False)
        if results.aic < aic_bestvalue:
            aic_bestvalue = results.aic
            pdq_bestvalue = params
            pdq_seasonal_best = seasonal_params
print("Best ARIMA with seasonality (SARIMAX) {} x {} model - AIC:{}".format(pdq_bestvalue,pdq_seasonal_best,aic_bestvalue))
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Best ARIMA with seasonality (SARIMAX) (1, 1, 1) x (1, 1, 1, 7) model - AIC:2802.513141419383

# %%
# Training the model on the full dataset and predict last 24 hours output
model =  SARIMAX(train,order = (1, 1, 1), 
                        seasonal_order =(1, 1, 1, 7),enforce_invertibility=False,
                             enforce_stationarity=False)
sarimax = model.fit()
sarimax.plot_diagnostics(figsize=(12, 12))
plt.show()

# %%
final = test.copy()
final['SARIMAX'] = sarimax.predict(start="2016-12-12", end="2017-03-31", dynamic=True)
plt.figure(figsize=(16,8))
plt.plot( train['DMA_225'], label='Train')
plt.plot(test['DMA_225'], label='Test')
plt.plot(final['SARIMAX'], label='SARIMAX')
plt.legend(loc='best')
plt.show()

# %%
testset = test.reset_index()
fd=pd.merge(testset, final.SARIMAX, on="Date_time")

# %%
# Calculate rmse of original and predicted value
rmse = np.sqrt(mean_squared_error(fd.DMA_225,fd.SARIMAX))
rmse = round(rmse, 3)
print (" The root mean square vaue on testset: ",rmse)
# Out:
#  The root mean square vaue on testset:  132.542

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(fd.Date_time, fd.DMA_225, color='red', label='original')
plt.plot(fd.Date_time, fd.SARIMAX, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()

# %% [markdown]
# # LSTM

# %%
dd = daily_data.values
train_size = int(len(dd)*0.7)
train_data = dd[:train_size]
test_data = dd[train_size:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.fit_transform(test_data)

# %%
def matrix_dataset(array_dataset, timesteps=1):
 mat_X, mat_Y = [], []
 for i in range(len(array_dataset)-timesteps-1):
  Z = i+timesteps
  m = array_dataset[i:Z, 0]
  mat_X.append(m)
  n = array_dataset[Z, 0]
  mat_Y.append(n)
 return np.array(mat_X), np.array( mat_Y)


look_back = 3
features = 1
X_train1, Y_train1 = matrix_dataset(train_scaled, look_back)
X_test1, Y_test1 = matrix_dataset(test_scaled, look_back)

# %%
X_train1 = X_train1.reshape((X_train1.shape[0],X_train1.shape[1],1))
X_test1 = X_test1.reshape( (X_test1.shape[0],X_test1.shape[1],1))

# %%
print('X_train shape:',X_train1.shape)
print('Y_train shape:', Y_train1.shape)
print('X_test shape:',X_test1.shape)
print('Y_test shape:',Y_test1.shape)
# Out:
# X_train shape: (251, 3, 1)
# Y_train shape: (251,)
# X_test shape: (106, 3, 1)
# Y_test shape: (106,)

# %%
model = Sequential()
model.add(LSTM(10,input_shape=(3, 1)))
model.add(Dropout(0.20))
model.add(Dense(7))
model.compile(loss='mean_absolute_error', optimizer='Adam')
y=model.fit(X_train1,Y_train1, epochs=100, batch_size=50, validation_data=(X_test1,Y_test1))
# Out:
# Epoch 1/100
# 6/6 [==============================] - 2s 104ms/step - loss: 0.1056 - val_loss: 0.0794
# Epoch 2/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0957 - val_loss: 0.0711
# Epoch 3/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0874 - val_loss: 0.0643
# Epoch 4/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0807 - val_loss: 0.0594
# Epoch 5/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0762 - val_loss: 0.0563
# Epoch 6/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0726 - val_loss: 0.0547
# Epoch 7/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0707 - val_loss: 0.0541
# Epoch 8/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0695 - val_loss: 0.0540
# Epoch 9/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0688 - val_loss: 0.0539
# Epoch 10/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0682 - val_loss: 0.0540
# Epoch 11/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0675 - val_loss: 0.0538
# Epoch 12/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0667 - val_loss: 0.0537
# Epoch 13/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0665 - val_loss: 0.0534
# Epoch 14/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0664 - val_loss: 0.0533
# Epoch 15/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0658 - val_loss: 0.0531
# Epoch 16/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0658 - val_loss: 0.0530
# Epoch 17/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0651 - val_loss: 0.0527
# Epoch 18/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0645 - val_loss: 0.0527
# Epoch 19/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0639 - val_loss: 0.0527
# Epoch 20/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0640 - val_loss: 0.0525
# Epoch 21/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0633 - val_loss: 0.0526
# Epoch 22/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0631 - val_loss: 0.0527
# Epoch 23/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0622 - val_loss: 0.0523
# Epoch 24/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0623 - val_loss: 0.0520
# Epoch 25/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0618 - val_loss: 0.0515
# Epoch 26/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0611 - val_loss: 0.0515
# Epoch 27/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0607 - val_loss: 0.0516
# Epoch 28/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0601 - val_loss: 0.0508
# Epoch 29/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0604 - val_loss: 0.0499
# Epoch 30/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0592 - val_loss: 0.0495
# Epoch 31/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0591 - val_loss: 0.0488
# Epoch 32/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0579 - val_loss: 0.0482
# Epoch 33/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0574 - val_loss: 0.0477
# Epoch 34/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0574 - val_loss: 0.0475
# Epoch 35/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0568 - val_loss: 0.0476
# Epoch 36/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0566 - val_loss: 0.0478
# Epoch 37/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0554 - val_loss: 0.0475
# Epoch 38/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0548 - val_loss: 0.0473
# Epoch 39/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0545 - val_loss: 0.0466
# Epoch 40/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0537 - val_loss: 0.0465
# Epoch 41/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0530 - val_loss: 0.0468
# Epoch 42/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0520 - val_loss: 0.0470
# Epoch 43/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0524 - val_loss: 0.0466
# Epoch 44/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0517 - val_loss: 0.0458
# Epoch 45/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0504 - val_loss: 0.0448
# Epoch 46/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0504 - val_loss: 0.0439
# Epoch 47/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0504 - val_loss: 0.0434
# Epoch 48/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0484 - val_loss: 0.0431
# Epoch 49/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0486 - val_loss: 0.0428
# Epoch 50/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0485 - val_loss: 0.0424
# Epoch 51/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0481 - val_loss: 0.0421
# Epoch 52/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0465 - val_loss: 0.0417
# Epoch 53/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0478 - val_loss: 0.0416
# Epoch 54/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0457 - val_loss: 0.0417
# Epoch 55/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0455 - val_loss: 0.0412
# Epoch 56/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0459 - val_loss: 0.0410
# Epoch 57/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0465 - val_loss: 0.0409
# Epoch 58/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0460 - val_loss: 0.0406
# Epoch 59/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0441 - val_loss: 0.0402
# Epoch 60/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0436 - val_loss: 0.0400
# Epoch 61/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0431 - val_loss: 0.0398
# Epoch 62/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0433 - val_loss: 0.0395
# Epoch 63/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0409 - val_loss: 0.0395
# Epoch 64/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0420 - val_loss: 0.0391
# Epoch 65/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0415 - val_loss: 0.0395
# Epoch 66/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0412 - val_loss: 0.0396
# Epoch 67/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0434 - val_loss: 0.0395
# Epoch 68/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0428 - val_loss: 0.0389
# Epoch 69/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0407 - val_loss: 0.0387
# Epoch 70/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0412 - val_loss: 0.0386
# Epoch 71/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0386
# Epoch 72/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0405 - val_loss: 0.0391
# Epoch 73/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0411 - val_loss: 0.0384
# Epoch 74/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0414 - val_loss: 0.0381
# Epoch 75/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0398 - val_loss: 0.0380
# Epoch 76/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0404 - val_loss: 0.0379
# Epoch 77/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0409 - val_loss: 0.0378
# Epoch 78/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0396 - val_loss: 0.0379
# Epoch 79/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0409 - val_loss: 0.0379
# Epoch 80/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0394 - val_loss: 0.0376
# Epoch 81/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0406 - val_loss: 0.0375
# Epoch 82/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0388 - val_loss: 0.0375
# Epoch 83/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0415 - val_loss: 0.0374
# Epoch 84/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0406 - val_loss: 0.0375
# Epoch 85/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0394 - val_loss: 0.0375
# Epoch 86/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0387 - val_loss: 0.0375
# Epoch 87/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0387 - val_loss: 0.0373
# Epoch 88/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0377 - val_loss: 0.0372
# Epoch 89/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0385 - val_loss: 0.0373
# Epoch 90/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0397 - val_loss: 0.0373
# Epoch 91/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0386 - val_loss: 0.0379
# Epoch 92/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0406 - val_loss: 0.0381
# Epoch 93/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0393 - val_loss: 0.0375
# Epoch 94/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0379 - val_loss: 0.0375
# Epoch 95/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0397 - val_loss: 0.0376
# Epoch 96/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0390 - val_loss: 0.0373
# Epoch 97/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0379 - val_loss: 0.0374
# Epoch 98/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0383 - val_loss: 0.0372
# Epoch 99/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0371 - val_loss: 0.0372
# Epoch 100/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0377 - val_loss: 0.0374

# %%
# Plot train loss and validation loss
def plot_loss (history, model_name):
    plt.figure(figsize = (10, 6))
    plt.plot(y.history['loss'])
    plt.plot(y.history['val_loss'])
    plt.title('Model Train vs Validation Loss for ' + model_name)
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')

# %%
plot_loss(y,'LSTM')

# %%
# Generate predictions
train_pred = model.predict(X_train1)
#evaluation = model.evaluate(x=X_test, y=y_test, verbose=1)
test_pred = model.predict(X_test1)
predictions = test_pred

# %%
# De-standardising the output to original value
train_pred = scaler.inverse_transform(train_pred)
y_train = scaler.inverse_transform([Y_train1])
test_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform([Y_test1])
predictions = test_pred

# %%
# To make a dataframe of original and predicted value:
lstm_df=[]
for i in range (0, len(predictions)):
  lstm_df.append((predictions[i][0]))
final_data = pd.DataFrame((y_test[0]))
#final_data = pd.DataFrame((Y_test))
final_data.rename(columns = {0:'original_value'}, inplace = True)
final_data['predicted_value'] = lstm_df

# %%
import math
from sklearn.metrics import mean_squared_error
testset = math.sqrt(mean_squared_error(final_data['original_value'], final_data['predicted_value']))
print("The RMSE prediction value on testset: ",testset)
# Out:
# The RMSE prediction value on testset:  91.41294396827703

# %%
final_df2= daily_data.reset_index()
# Comparing the forecasts with the actual values
yhat = [x[0] for x in model.predict(X_test1)]
y = [y for y in Y_test1]
# Creating the frame to store both predictions
days = final_df2[['Date_time']].values[-len(y):]
df = pd.DataFrame(days,columns = ['Date_time'])
result = pd.concat([df, final_data], axis=1, join='inner')
result.shape
# Out:
# (106, 3)

# %%
# Plotting original and predicted graph:
plt.figure(figsize=(20, 12))
plt.plot(result.Date_time, result.original_value, color='red', label='original')
plt.plot(result.Date_time, result.predicted_value, color='blue', label='forecast', alpha=0.7)
plt.title('Originial vs forecast')
plt.legend()
plt.show()
